# %% [markdown]
# # ResNet 18 modified with generated data

# %% [markdown]
# ## Import packages

# %%
import sys
sys.path.append('/home/eym16/anaconda3/lib/python3.6/site-packages')

import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import bisect
import pandas as pd

# %% [markdown]
# ## Device configuration

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(torch.cuda.device_count())
# Out:
# 0

# %% [markdown]
# ## Data generation

# %%
epsilon = 10**(-4)

import random

#frames generator class
class Frame_generator(object):

    def __init__(self, dim, train_samples=4):
#         self.array = array
        self.dim = dim
        self.train_samples = train_samples
        self.zeros = np.zeros((dim, dim))
#         self.itemindex = self.itemindex_fun
#         self.indices = self.datasets_indices
#         self.frame = self.frame(x=array)
        
#     def itemindex_fun(self,value):
#         itemindex = np.where(self.array==value)
#         return itemindex
    
#     def datasets_indices(self, train_samples):
#         indices = np.arange(len(self.itemindex(1)[0]))
#         one_indices =  random.sample(list(indices), train_samples)
#         return(one_indices)

    #using self.definitions for the functions didn't work out
    #forward part doesn't work
    def frame(self, loc1, loc2):
        res = np.copy(self.zeros)
        for i,j in zip(loc1,loc2):
#             print('i:', i)
#             print('j:', j)
            res[i][j]+=1
            if i==0 and j==0:
                res[i][j+1]+=1
                res[i+1][j]+=1
                res[i+1][j+1]+=1
            elif i==0 and j==self.dim-1:
                res[i][j-1]+=1
                res[i+1][j-1]+=1
                res[i+1][j]+=1
            elif i==self.dim-1 and j==0:
                res[i-1][j]+=1
                res[i-1][j+1]+=1
                res[i][j+1]+=1
            elif i==self.dim-1 and j==self.dim-1:
                res[i-1][j]+=1
                res[i-1][j-1]+=1
                res[i][j-1]+=1
            elif i==0:
                res[i][j-1]+=1
                res[i][j+1]+=1
                res[i+1][j-1]+=1
                res[i+1][j]+=1
                res[i+1][j+1]+=1
            elif i==self.dim-1:
                res[i][j-1]+=1
                res[i][j+1]+=1
                res[i-1][j-1]+=1
                res[i-1][j]+=1
                res[i-1][j+1]+=1
            elif j==0:
                res[i-1][j]+=1
                res[i+1][j]+=1
                res[i-1][j+1]+=1
                res[i][j+1]+=1
                res[i+1][j+1]+=1
            elif j==self.dim-1:
                res[i-1][j]+=1
                res[i+1][j]+=1
                res[i-1][j-1]+=1
                res[i][j-1]+=1
                res[i+1][j-1]+=1
            else:
                res[i-1][j-1]+=1
                res[i-1][j]+=1
                res[i-1][j+1]+=1
                res[i][j-1]+=1
                res[i][j+1]+=1
                res[i+1][j-1]+=1
                res[i+1][j]+=1
                res[i+1][j+1]+=1

        return(res)
    
    #produce dataset
    def frames(self, n_frames, loc1, loc2):
        frames = np.empty((n_frames, self.dim, self.dim))
        for i in range(n_frames):
            loc1_tmp = loc1[loc1[:,i].nonzero()[0],i]
            loc2_tmp = loc2[loc2[:,i].nonzero()[0],i]
            intervals = np.arange(0,1,1/self.dim)
            loc1_index = []
            loc2_index = []
#             print(loc1_tmp.shape)
            for n in range(loc1_tmp.shape[0]):
#                 print(loc1_tmp)
                loc1_index.append(bisect.bisect_left(intervals, loc1_tmp[n])-1)
                loc2_index.append(bisect.bisect_left(intervals, loc2_tmp[n])-1)
            frames[i][:][:]=self.frame(loc1_index, loc2_index)
        return frames

# final image generator
def final_image(dim, n_frames, p_1_1=0.05):
    n = np.random.poisson(lam=10, size=1)
    #if n==0, generate one point
    n = max(n,1)
    loc_mat = np.random.rand(n[0],2)
    intervals = np.arange(0,1,1/dim)
    loc1 = []
    loc2 = []
    for n in range(loc_mat.shape[0]):
        loc1.append(bisect.bisect_left(intervals, loc_mat[n,0])-1)
        loc2.append(bisect.bisect_left(intervals, loc_mat[n,1])-1)
    x = np.zeros((dim,dim))
    for i,j in zip(loc1,loc2):
        x[i][j] += 1
    #generate location matrices
#     print(loc_mat[:,0].shape)
    
    #correlation adjustment
    #define correlation parameters
    a_1 = 4/loc_mat.shape[0]
    a_1 = np.clip(a_1, a_min=epsilon, a_max=1-epsilon)
    a_2 = 1-a_1
    p_1_1=p_1_1
    p_2_2=(a_2-a_1*(1-p_1_1))/a_2
    #define correlation matrix
    binom = np.zeros((loc_mat.shape[0],n_frames))
    binom[:,0] = np.random.binomial(n=1,p=min(1,4/loc_mat.shape[0]),size=loc_mat.shape[0])
    for j in range(1,n_frames):
        for i in range(loc_mat.shape[0]):
            if binom[i,j-1]==1:
                binom[i,j]= np.random.binomial(n=1,p=min(1,p_1_1),size=1)
            else:
                binom[i,j]= np.random.binomial(n=1,p=min(1,1-p_2_2),size=1)
#     binom = np.random.binomial(n=1,p=min(1,4/loc_mat.shape[0]),size=(loc_mat.shape[0],n_frames))
#     print('binom shape: ', binom.shape)
#     print(binom)
    loc1 = np.multiply(np.reshape(loc_mat[:,0],(loc_mat.shape[0],-1)),binom)
    loc2 = np.multiply(np.reshape(loc_mat[:,1],(loc_mat.shape[0],-1)),binom)
    loc1 = loc1[loc1[:,:].nonzero()[0],:]
    loc2 = loc2[loc2[:,:].nonzero()[0],:]
    return(x, loc1, loc2)


# images generator function
def frames_data_fun(n_images, n_frames, dim):
    labels = np.zeros((n_images, 2, dim, dim))
    data = np.empty((n_images, n_frames, dim, dim))
    for n in range(n_images):
        x, loc1, loc2 = final_image(dim, n_frames)
        tmp = Frame_generator(dim)
        #30 is burn-in samples
        frames = tmp.frames(n_frames=n_frames, loc1=loc1, loc2=loc2)
#         print(frames.shape)
        labels[n][1][:][:]=x
        m = (x!=0)
        labels[n][0][:][:]=1*m
        data[n][:][:][:]=frames
    return(labels, data)

# call images generator function
# 1000 images, 10000 frames, 100X100 dimension
#30 burn-in samples
n_images = 1600
n_frames = 1000
dim = 10
res = frames_data_fun(n_images=n_images, n_frames=n_frames+30, dim=dim)
labels = res[0]
print(labels.shape)
data = res[1][:,-n_frames:,:,:]

print(data.shape)
# print('data frame:', data[2,3,:,:])
# print('lable:', labels[2,:,:])
# Out:
# (1600, 2, 10, 10)
# (1600, 1000, 10, 10)

# %% [markdown]
# ## Hyper parameters

# %%
# Hyper-parameters
num_epochs = 200
learning_rate = 0.001
channel_dim = data.shape[1]
input_dim=data.shape[2]
data_samples = len(data)
train_samples = round(0.8*data_samples)
conv_layers0 = 16

# # Image preprocessing modules
# transform = transforms.Compose([
#     transforms.Pad(4),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomCrop(32),
# transforms.ToTensor()])

# %% [markdown]
# ## Train and test datasets

# %%
import random

# Data loader
def datasets_indices(data_samples, train_samples):    
    indices = np.arange(data_samples)
    #print(indices)
    train_indices =  random.sample(list(indices), train_samples)
    #print(train_indices)
    test_indices = list(set(list(indices))-set(train_indices))
    #print(test_indices)
    return(train_indices, test_indices)

indices = datasets_indices(data_samples, train_samples)
train_loader = data[indices[0],:,:,:]
train_labels = labels[indices[0],:,:]
test_loader = data[indices[1],:,:,:]
test_labels = labels[indices[1],:,:]

# define mini-batch
train_loader = torch.utils.data.DataLoader(dataset=train_loader,
                                           batch_size=32,shuffle=False)
train_labels = torch.utils.data.DataLoader(dataset=train_labels,
                                           batch_size=32,shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_loader,
                                           batch_size=32,shuffle=False)
test_labels = torch.utils.data.DataLoader(dataset=test_labels,
                                           batch_size=32,shuffle=False)

# datasets shapes
#print(train_loader.shape)
#print(test_loader.shape)

# %% [markdown]
# ## Define a model
# ResNet 18 modified version (terminal fully connected layer is replaced with another convolution layer).

# %%
epsilon = 10**(-4)

# 3x3 convolution

def conv3x3(in_channels, out_channels, stride=1, input_dim=input_dim):
    return nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                     stride=stride, padding=np.ceil((input_dim*stride-input_dim-stride+3)/2), bias=True)

# Residual block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv3x3(in_channels, out_channels, stride)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = conv3x3(out_channels, out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.downsample = downsample
        
    def forward(self, x):
        residual = x
        out = self.conv1(x)
        #print("block conv1 size:", out.shape)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        #print("block conv2 size:", out.shape)
        out = self.bn2(out)
        if self.downsample:
            residual = self.downsample(x)
        out += residual
        out = self.relu(out)
        #print("block size:", out.shape)
        return out

# ResNet
class ResNet(nn.Module):
    def __init__(self, block, layers, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = conv_layers0
        self.conv = conv3x3(channel_dim, conv_layers0)
        self.bn = nn.BatchNorm2d(conv_layers0)
        self.relu = nn.ReLU(inplace=True)
        self.layer1 = self.make_layer(block, conv_layers0, layers[0])
        self.layer2 = self.make_layer(block, conv_layers0*2, layers[0], 2)
        self.layer3 = self.make_layer(block, conv_layers0*4, layers[1], 2)
        self.conv_final = nn.Conv2d(conv_layers0*4, 2, kernel_size=1, 
                     stride=1, padding=0, bias=True)
        self.out_act = nn.Sigmoid()
        
    def make_layer(self, block, out_channels, blocks, stride=1):
        downsample = None
        if (stride != 1) or (self.in_channels != out_channels):
            downsample = nn.Sequential(
                conv3x3(self.in_channels, out_channels, stride=stride),
                nn.BatchNorm2d(out_channels))
        layers = []
        layers.append(block(self.in_channels, out_channels, stride, downsample))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels))
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.conv_final(out)
        out0 = torch.unsqueeze(out[:,0,:,:],1)
        out1 = torch.unsqueeze(out[:,1,:,:],1)
        #replace sigmoid by ReLu
#         out = self.out_act(out)
        out0 = self.out_act(out0)
        out0 = out0.clamp(min=epsilon, max=1-epsilon)
        out1 = self.relu(out1)
        out = torch.cat((out0,out1),1)
        #print("net size:", out.shape)
        return out

# %% [markdown]
# ## Run the model
#  - Loss function: absolute deviation
#  - Train the model on the train data.
#  - Test the model on the test data and report model accuracy.

# %%
# epsilon = 10**(-6)

# Check if multiple GPUs are available, and if so parallelize the computations
model = ResNet(ResidualBlock, [2, 2, 2, 2]).double().to(device)
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    model = nn.DataParallel(model)
model.to(device)

#loss function
class Loss(torch.nn.Module):

    def __init__(self):
        super(Loss,self).__init__()

    def forward(self,x,y):
#         print('x shape:', x.shape)
#         print(x[0,:,:])
        loss_layer0 = -(y[:,0,:,:]*torch.log(x[:,0,:,:])*10+(1-y[:,0,:,:])*torch.log(1-x[:,0,:,:]))
#         print(loss_layer0)
        loss_layer0 = torch.sum(loss_layer0)
        loss_layer1 = 0
        for image in range(x.shape[0]):
            for i in range(x.shape[2]):
                for j in range(x.shape[3]):
                    if y[image,0,i,j]==1:
                        loss_layer1+=abs(y[image,1,i,j]-x[image,1,i,j])/(x.shape[2]^2)
        totloss = loss_layer0+loss_layer1
        return totloss

# Loss and optimizer
criterion = Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# For updating learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


# Train the model
total_step = len(train_loader)
# print(input_dim)
# print(total_step)
curr_lr = learning_rate
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(zip(train_loader, train_labels)):
        images = images.to(device)
        labels = labels.to(device)
#         print(images.shape)
#         print(labels.shape)
        # Forward pass
        outputs = model(images.view(-1,channel_dim,input_dim,input_dim))
        outputs = outputs.view(-1,2,input_dim,input_dim)
#         print('outputs dim:', outputs.shape)
#         print(outputs.shape, labels.shape)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # print train run results
        if (i+1) % 5 == 0:
            print ("Epoch [{}/{}], Step [{}/{}] Loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

    # Decay learning rate
    if (epoch+1) % 20 == 0:
        curr_lr /= 3
        update_lr(optimizer, curr_lr)
        torch.save(model.state_dict(), 'resnet.ckpt')
        print('model:', epoch)

# Test the model (train data)
print('################')
print('convolution layers:({},{},{})'.format(conv_layers0, conv_layers0*2, conv_layers0*4))
print('################')
print('train data results')
model.eval()
with torch.no_grad():
    correct = 0
    semi_correct = 0
    total = 0
    total_ones = 0
    total_zeros = 0
    correct_ones = 0
    correct_zeros = 0
    for i, (images,labels) in enumerate(zip(train_loader, train_labels)):
        images = images.to(device)
        labels = labels.to(device)
        #print(images.shape)
        outputs = model(images.view(-1,channel_dim,input_dim,input_dim))
        outputs = outputs.view(-1,2,input_dim,input_dim)
        predicted = outputs.data.round()
#         print('predicted shape:', predicted.shape)
#         print('labels shape:', labels.shape)
#         print(labels.shape[0])
        total += labels.shape[0]*input_dim*input_dim
        m = (labels[:,0,:,:]>0)*(predicted[:,0,:,:] == labels[:,0,:,:])
        correct += (predicted[:,0,:,:] == labels[:,0,:,:]).sum().item()-(m*(predicted[:,1,:,:] != labels[:,1,:,:])).sum().item()
        semi_correct += (predicted[:,0,:,:] == labels[:,0,:,:]).sum().item()
        total_ones +=  (labels[:,0,:,:]==1).sum().item()
        total_zeros += (labels[:,0,:,:]==0).sum().item()
        correct_ones += ((predicted[:,0,:,:] == labels[:,0,:,:])*(labels[:,0,:,:]==1)).sum().item()
        correct_zeros += ((predicted[:,0,:,:] == labels[:,0,:,:])*(labels[:,0,:,:]==0)).sum().item()
print(correct_ones, total_ones, correct_zeros, total_zeros)
print('accuracy:', correct/total*100, '%')
print('semi_correct:', semi_correct/total*100, '%')
print('correct ones:', correct_ones/total_ones*100, '%')
print('correct zeros:', correct_zeros/total_zeros*100, '%')

with open('out.txt', 'a') as f:
    print('\n####\n','convolution layers:({},{},{}), '.format(conv_layers0, conv_layers0*2, conv_layers0*4),'\n','images:', data_samples, ', channels:', data.shape[1], ', dim:', data.shape[2], ', epoch:', num_epochs, '\n', 'Accuracy of the model on the train images: {} %'.format(100 * correct / total), file=f, sep='')

# Test the model (test data)
print('################')
print('test data results')
def test_results(threshold):
    print(threshold)
    model.eval()
    res = []
    for j in threshold:
        print('j:', j)
        with torch.no_grad():
            correct = 0
            semi_correct = 0
            total = 0
            total_ones = 0
            total_zeros = 0
            correct_ones = 0
            correct_zeros = 0
            for i, (images,labels) in enumerate(zip(test_loader, test_labels)):
                images = images.to(device)
                labels = labels.to(device)
                #print(images.shape)
                outputs = model(images.view(-1,channel_dim,input_dim,input_dim))
                outputs = outputs.view(-1,2,input_dim,input_dim)
#                 print('outputs', (outputs>j))
                predicted = ((outputs>j)*1).double()
        #         print('predicted shape:', predicted.shape)
        #         print('labels shape:', labels.shape)
        #         print(labels.shape[0])
                total += labels.shape[0]*input_dim*input_dim
#                 print('predicted:', predicted[:,0,:,:])
#                 print('labels:', labels[:,0,:,:])
                m = (labels[:,0,:,:]>0)*(predicted[:,0,:,:] == labels[:,0,:,:])
                correct += (predicted[:,0,:,:] == labels[:,0,:,:]).sum().item()-(m*(predicted[:,1,:,:] != labels[:,1,:,:])).sum().item()
                semi_correct += (predicted[:,0,:,:] == labels[:,0,:,:]).sum().item()
                total_ones +=  (labels[:,0,:,:]==1).sum().item()
                total_zeros += (labels[:,0,:,:]==0).sum().item()
                correct_ones += ((predicted[:,0,:,:] == labels[:,0,:,:])*(labels[:,0,:,:]==1)).sum().item()
                correct_zeros += ((predicted[:,0,:,:] == labels[:,0,:,:])*(labels[:,0,:,:]==0)).sum().item()
            res.append([correct_ones,total_ones,correct_zeros,total_zeros])
#         print('shape:', len(res))
        res_out = pd.DataFrame(data=res, columns=['correct_ones','total_ones','correct_zeros','total_zeros'])
#         print(correct_ones, total_ones, correct_zeros, total_zeros)
        print('accuracy:', correct/total*100, '%')
        print('semi_correct:', semi_correct/total*100, '%')
        print('correct ones:', correct_ones/total_ones*100, '%')
        print('correct zeros:', correct_zeros/total_zeros*100, '%')

        with open('out.txt', 'a') as f:
            print('\n', 'threshold: ', j,', ', 'Accuracy of the model on the test images: {} %'.format(100 * correct / total), file=f, sep='')
    return(res_out)

threshold = [0.1,0.3,0.5,0.7,0.9]

res = test_results(threshold)
print('res:\n', res, type(res))
# Save the model checkpoint
torch.save(model.state_dict(), 'resnet.ckpt')
# Out:
# Epoch [1/200], Step [5/40] Loss: 4284.2334
# Epoch [1/200], Step [10/40] Loss: 4077.2184
# Epoch [1/200], Step [15/40] Loss: 4164.3777
# Epoch [1/200], Step [20/40] Loss: 3927.0919
# Epoch [1/200], Step [25/40] Loss: 3897.2735
# Epoch [1/200], Step [30/40] Loss: 3875.6938
# Epoch [1/200], Step [35/40] Loss: 3850.8255
# Epoch [1/200], Step [40/40] Loss: 3385.7934
# Epoch [2/200], Step [5/40] Loss: 3339.5701
# Epoch [2/200], Step [10/40] Loss: 3165.1709
# Epoch [2/200], Step [15/40] Loss: 3082.5507
# Epoch [2/200], Step [20/40] Loss: 2811.6181
# Epoch [2/200], Step [25/40] Loss: 2706.5546
# Epoch [2/200], Step [30/40] Loss: 2748.7594
# Epoch [2/200], Step [35/40] Loss: 2853.9761
# Epoch [2/200], Step [40/40] Loss: 2211.6273
# Epoch [3/200], Step [5/40] Loss: 2388.5370
# Epoch [3/200], Step [10/40] Loss: 2169.8878
# Epoch [3/200], Step [15/40] Loss: 2180.4758
# Epoch [3/200], Step [20/40] Loss: 2033.2998
# Epoch [3/200], Step [25/40] Loss: 1939.2534
# Epoch [3/200], Step [30/40] Loss: 2033.3249
# Epoch [3/200], Step [35/40] Loss: 2148.5024
# Epoch [3/200], Step [40/40] Loss: 1634.3009
# Epoch [4/200], Step [5/40] Loss: 1676.6230
# Epoch [4/200], Step [10/40] Loss: 1662.4464
# Epoch [4/200], Step [15/40] Loss: 1608.3704
# Epoch [4/200], Step [20/40] Loss: 1494.5906
# Epoch [4/200], Step [25/40] Loss: 1442.7209
# Epoch [4/200], Step [30/40] Loss: 1520.1434
# Epoch [4/200], Step [35/40] Loss: 1648.6489
# Epoch [4/200], Step [40/40] Loss: 1311.1478
# Epoch [5/200], Step [5/40] Loss: 1498.7654
# Epoch [5/200], Step [10/40] Loss: 1325.8151
# Epoch [5/200], Step [15/40] Loss: 1347.3684
# Epoch [5/200], Step [20/40] Loss: 1209.6339
# Epoch [5/200], Step [25/40] Loss: 1150.4557
# Epoch [5/200], Step [30/40] Loss: 1188.4537
# Epoch [5/200], Step [35/40] Loss: 1381.3126
# Epoch [5/200], Step [40/40] Loss: 1088.8546
# Epoch [6/200], Step [5/40] Loss: 1177.8376
# Epoch [6/200], Step [10/40] Loss: 1246.1898
# Epoch [6/200], Step [15/40] Loss: 1083.3279
# Epoch [6/200], Step [20/40] Loss: 1037.5213
# Epoch [6/200], Step [25/40] Loss: 981.9121
# Epoch [6/200], Step [30/40] Loss: 1076.0339
# Epoch [6/200], Step [35/40] Loss: 1149.7226
# Epoch [6/200], Step [40/40] Loss: 831.0518
# Epoch [7/200], Step [5/40] Loss: 908.6519
# Epoch [7/200], Step [10/40] Loss: 871.9865
# Epoch [7/200], Step [15/40] Loss: 998.0789
# Epoch [7/200], Step [20/40] Loss: 936.5088
# Epoch [7/200], Step [25/40] Loss: 773.1408
# Epoch [7/200], Step [30/40] Loss: 880.4069
# Epoch [7/200], Step [35/40] Loss: 1112.8285
# Epoch [7/200], Step [40/40] Loss: 842.0533
# Epoch [8/200], Step [5/40] Loss: 760.1601
# Epoch [8/200], Step [10/40] Loss: 752.2890
# Epoch [8/200], Step [15/40] Loss: 707.3364
# Epoch [8/200], Step [20/40] Loss: 662.1967
# Epoch [8/200], Step [25/40] Loss: 652.1649
# Epoch [8/200], Step [30/40] Loss: 754.6235
# Epoch [8/200], Step [35/40] Loss: 840.3512
# Epoch [8/200], Step [40/40] Loss: 663.4203
# Epoch [9/200], Step [5/40] Loss: 682.5277
# Epoch [9/200], Step [10/40] Loss: 666.3048
# Epoch [9/200], Step [15/40] Loss: 608.6676
# Epoch [9/200], Step [20/40] Loss: 516.4274
# Epoch [9/200], Step [25/40] Loss: 494.0836
# Epoch [9/200], Step [30/40] Loss: 508.8607
# Epoch [9/200], Step [35/40] Loss: 620.7397
# Epoch [9/200], Step [40/40] Loss: 465.1158
# Epoch [10/200], Step [5/40] Loss: 480.0486
# Epoch [10/200], Step [10/40] Loss: 494.7298
# Epoch [10/200], Step [15/40] Loss: 477.9542
# Epoch [10/200], Step [20/40] Loss: 471.4083
# Epoch [10/200], Step [25/40] Loss: 418.3990
# Epoch [10/200], Step [30/40] Loss: 467.2149
# Epoch [10/200], Step [35/40] Loss: 505.3820
# Epoch [10/200], Step [40/40] Loss: 471.3637
# Epoch [11/200], Step [5/40] Loss: 562.5120
# Epoch [11/200], Step [10/40] Loss: 402.2939
# Epoch [11/200], Step [15/40] Loss: 496.5751
# Epoch [11/200], Step [20/40] Loss: 451.2574
# Epoch [11/200], Step [25/40] Loss: 469.2577
# Epoch [11/200], Step [30/40] Loss: 410.0161
# Epoch [11/200], Step [35/40] Loss: 525.2666
# Epoch [11/200], Step [40/40] Loss: 531.3597
# Epoch [12/200], Step [5/40] Loss: 496.5047
# Epoch [12/200], Step [10/40] Loss: 372.3294
# Epoch [12/200], Step [15/40] Loss: 444.5297
# Epoch [12/200], Step [20/40] Loss: 430.9252
# Epoch [12/200], Step [25/40] Loss: 389.3061
# Epoch [12/200], Step [30/40] Loss: 494.8055
# Epoch [12/200], Step [35/40] Loss: 383.5550
# Epoch [12/200], Step [40/40] Loss: 352.6221
# Epoch [13/200], Step [5/40] Loss: 417.6803
# Epoch [13/200], Step [10/40] Loss: 423.4322
# Epoch [13/200], Step [15/40] Loss: 336.6643
# Epoch [13/200], Step [20/40] Loss: 307.1662
# Epoch [13/200], Step [25/40] Loss: 280.5736
# Epoch [13/200], Step [30/40] Loss: 349.0043
# Epoch [13/200], Step [35/40] Loss: 330.0767
# Epoch [13/200], Step [40/40] Loss: 251.9798
# Epoch [14/200], Step [5/40] Loss: 255.5343
# Epoch [14/200], Step [10/40] Loss: 212.1353
# Epoch [14/200], Step [15/40] Loss: 242.7823
# Epoch [14/200], Step [20/40] Loss: 260.0170
# Epoch [14/200], Step [25/40] Loss: 207.6819
# Epoch [14/200], Step [30/40] Loss: 221.6771
# Epoch [14/200], Step [35/40] Loss: 246.1868
# Epoch [14/200], Step [40/40] Loss: 212.4382
# Epoch [15/200], Step [5/40] Loss: 188.4867
# Epoch [15/200], Step [10/40] Loss: 230.7109
# Epoch [15/200], Step [15/40] Loss: 223.5425
# Epoch [15/200], Step [20/40] Loss: 293.1239
# Epoch [15/200], Step [25/40] Loss: 178.4388
# Epoch [15/200], Step [30/40] Loss: 194.4832
# Epoch [15/200], Step [35/40] Loss: 231.6305
# Epoch [15/200], Step [40/40] Loss: 195.7475
# Epoch [16/200], Step [5/40] Loss: 200.7793
# Epoch [16/200], Step [10/40] Loss: 125.2232
# Epoch [16/200], Step [15/40] Loss: 198.8818
# Epoch [16/200], Step [20/40] Loss: 129.5372
# Epoch [16/200], Step [25/40] Loss: 185.0260
# Epoch [16/200], Step [30/40] Loss: 202.4967
# Epoch [16/200], Step [35/40] Loss: 225.3717
# Epoch [16/200], Step [40/40] Loss: 159.0020
# Epoch [17/200], Step [5/40] Loss: 162.2643
# Epoch [17/200], Step [10/40] Loss: 127.5890
# Epoch [17/200], Step [15/40] Loss: 143.5001
# Epoch [17/200], Step [20/40] Loss: 111.6093
# Epoch [17/200], Step [25/40] Loss: 138.8419
# Epoch [17/200], Step [30/40] Loss: 172.5190
# Epoch [17/200], Step [35/40] Loss: 180.6267
# Epoch [17/200], Step [40/40] Loss: 175.2503
# Epoch [18/200], Step [5/40] Loss: 151.5290
# Epoch [18/200], Step [10/40] Loss: 103.5640
# Epoch [18/200], Step [15/40] Loss: 194.6060
# Epoch [18/200], Step [20/40] Loss: 151.5023
# Epoch [18/200], Step [25/40] Loss: 143.5438
# Epoch [18/200], Step [30/40] Loss: 144.9980
# Epoch [18/200], Step [35/40] Loss: 172.7848
# Epoch [18/200], Step [40/40] Loss: 125.3400
# Epoch [19/200], Step [5/40] Loss: 187.4043
# Epoch [19/200], Step [10/40] Loss: 197.8556
# Epoch [19/200], Step [15/40] Loss: 107.6322
# Epoch [19/200], Step [20/40] Loss: 118.7152
# Epoch [19/200], Step [25/40] Loss: 106.4848
# Epoch [19/200], Step [30/40] Loss: 92.8715
# Epoch [19/200], Step [35/40] Loss: 163.6925
# Epoch [19/200], Step [40/40] Loss: 110.6949
# Epoch [20/200], Step [5/40] Loss: 172.8955
# Epoch [20/200], Step [10/40] Loss: 117.3165
# Epoch [20/200], Step [15/40] Loss: 196.5766
# Epoch [20/200], Step [20/40] Loss: 193.0569
# Epoch [20/200], Step [25/40] Loss: 147.8162
# Epoch [20/200], Step [30/40] Loss: 182.3195
# Epoch [20/200], Step [35/40] Loss: 177.3667
# Epoch [20/200], Step [40/40] Loss: 145.7081
# model: 19
# Epoch [21/200], Step [5/40] Loss: 126.3901
# Epoch [21/200], Step [10/40] Loss: 98.2307
# Epoch [21/200], Step [15/40] Loss: 121.0540
# Epoch [21/200], Step [20/40] Loss: 89.9032
# Epoch [21/200], Step [25/40] Loss: 60.9139
# Epoch [21/200], Step [30/40] Loss: 67.3441
# Epoch [21/200], Step [35/40] Loss: 79.0194
# Epoch [21/200], Step [40/40] Loss: 58.7729
# Epoch [22/200], Step [5/40] Loss: 52.1997
# Epoch [22/200], Step [10/40] Loss: 38.4452
# Epoch [22/200], Step [15/40] Loss: 48.3440
# Epoch [22/200], Step [20/40] Loss: 35.8021
# Epoch [22/200], Step [25/40] Loss: 28.8064
# Epoch [22/200], Step [30/40] Loss: 30.6868
# Epoch [22/200], Step [35/40] Loss: 32.9327
# Epoch [22/200], Step [40/40] Loss: 34.7967
# Epoch [23/200], Step [5/40] Loss: 28.9806
# Epoch [23/200], Step [10/40] Loss: 22.0156
# Epoch [23/200], Step [15/40] Loss: 28.0750
# Epoch [23/200], Step [20/40] Loss: 20.6207
# Epoch [23/200], Step [25/40] Loss: 24.1941
# Epoch [23/200], Step [30/40] Loss: 18.7268
# Epoch [23/200], Step [35/40] Loss: 24.0516
# Epoch [23/200], Step [40/40] Loss: 25.4381
# Epoch [24/200], Step [5/40] Loss: 22.9963
# Epoch [24/200], Step [10/40] Loss: 18.1337
# Epoch [24/200], Step [15/40] Loss: 22.5422
# Epoch [24/200], Step [20/40] Loss: 16.1161
# Epoch [24/200], Step [25/40] Loss: 19.6967
# Epoch [24/200], Step [30/40] Loss: 15.2601
# Epoch [24/200], Step [35/40] Loss: 19.5696
# Epoch [24/200], Step [40/40] Loss: 20.6001
# Epoch [25/200], Step [5/40] Loss: 18.4806
# Epoch [25/200], Step [10/40] Loss: 14.6954
# Epoch [25/200], Step [15/40] Loss: 18.4960
# Epoch [25/200], Step [20/40] Loss: 13.6426
# Epoch [25/200], Step [25/40] Loss: 16.8937
# Epoch [25/200], Step [30/40] Loss: 13.3026
# Epoch [25/200], Step [35/40] Loss: 16.8274
# Epoch [25/200], Step [40/40] Loss: 17.4383
# Epoch [26/200], Step [5/40] Loss: 15.6769
# Epoch [26/200], Step [10/40] Loss: 12.8675
# Epoch [26/200], Step [15/40] Loss: 15.5943
# Epoch [26/200], Step [20/40] Loss: 12.0983
# Epoch [26/200], Step [25/40] Loss: 14.8029
# Epoch [26/200], Step [30/40] Loss: 11.9021
# Epoch [26/200], Step [35/40] Loss: 14.9966
# Epoch [26/200], Step [40/40] Loss: 15.1409
# Epoch [27/200], Step [5/40] Loss: 13.8433
# Epoch [27/200], Step [10/40] Loss: 11.6641
# Epoch [27/200], Step [15/40] Loss: 13.5860
# Epoch [27/200], Step [20/40] Loss: 11.0708
# Epoch [27/200], Step [25/40] Loss: 13.0114
# Epoch [27/200], Step [30/40] Loss: 10.8642
# Epoch [27/200], Step [35/40] Loss: 13.6761
# Epoch [27/200], Step [40/40] Loss: 13.4293
# Epoch [28/200], Step [5/40] Loss: 12.5589
# Epoch [28/200], Step [10/40] Loss: 10.8048
# Epoch [28/200], Step [15/40] Loss: 12.1276
# Epoch [28/200], Step [20/40] Loss: 10.2937
# Epoch [28/200], Step [25/40] Loss: 11.4608
# Epoch [28/200], Step [30/40] Loss: 10.0418
# Epoch [28/200], Step [35/40] Loss: 12.6456
# Epoch [28/200], Step [40/40] Loss: 12.0606
# Epoch [29/200], Step [5/40] Loss: 11.6171
# Epoch [29/200], Step [10/40] Loss: 10.1178
# Epoch [29/200], Step [15/40] Loss: 11.0297
# Epoch [29/200], Step [20/40] Loss: 9.6571
# Epoch [29/200], Step [25/40] Loss: 10.2402
# Epoch [29/200], Step [30/40] Loss: 9.3749
# Epoch [29/200], Step [35/40] Loss: 11.7902
# Epoch [29/200], Step [40/40] Loss: 10.9780
# Epoch [30/200], Step [5/40] Loss: 10.8518
# Epoch [30/200], Step [10/40] Loss: 9.5452
# Epoch [30/200], Step [15/40] Loss: 10.1463
# Epoch [30/200], Step [20/40] Loss: 9.1189
# Epoch [30/200], Step [25/40] Loss: 9.2467
# Epoch [30/200], Step [30/40] Loss: 8.8096
# Epoch [30/200], Step [35/40] Loss: 11.1029
# Epoch [30/200], Step [40/40] Loss: 10.1617
# Epoch [31/200], Step [5/40] Loss: 10.2147
# Epoch [31/200], Step [10/40] Loss: 9.0611
# Epoch [31/200], Step [15/40] Loss: 9.4423
# Epoch [31/200], Step [20/40] Loss: 8.6550
# Epoch [31/200], Step [25/40] Loss: 8.4440
# Epoch [31/200], Step [30/40] Loss: 8.3454
# Epoch [31/200], Step [35/40] Loss: 10.5039
# Epoch [31/200], Step [40/40] Loss: 9.4836
# Epoch [32/200], Step [5/40] Loss: 9.6847
# Epoch [32/200], Step [10/40] Loss: 8.6535
# Epoch [32/200], Step [15/40] Loss: 8.8433
# Epoch [32/200], Step [20/40] Loss: 8.2556
# Epoch [32/200], Step [25/40] Loss: 7.8350
# Epoch [32/200], Step [30/40] Loss: 7.9354
# Epoch [32/200], Step [35/40] Loss: 10.0177
# Epoch [32/200], Step [40/40] Loss: 8.9661
# Epoch [33/200], Step [5/40] Loss: 9.2349
# Epoch [33/200], Step [10/40] Loss: 8.2820
# Epoch [33/200], Step [15/40] Loss: 8.3263
# Epoch [33/200], Step [20/40] Loss: 7.9229
# Epoch [33/200], Step [25/40] Loss: 7.3451
# Epoch [33/200], Step [30/40] Loss: 7.5688
# Epoch [33/200], Step [35/40] Loss: 9.5554
# Epoch [33/200], Step [40/40] Loss: 8.4875
# Epoch [34/200], Step [5/40] Loss: 8.8533
# Epoch [34/200], Step [10/40] Loss: 7.9783
# Epoch [34/200], Step [15/40] Loss: 7.8890
# Epoch [34/200], Step [20/40] Loss: 7.6343
# Epoch [34/200], Step [25/40] Loss: 6.9469
# Epoch [34/200], Step [30/40] Loss: 7.2489
# Epoch [34/200], Step [35/40] Loss: 9.1893
# Epoch [34/200], Step [40/40] Loss: 8.1064
# Epoch [35/200], Step [5/40] Loss: 8.5271
# Epoch [35/200], Step [10/40] Loss: 7.7093
# Epoch [35/200], Step [15/40] Loss: 7.5050
# Epoch [35/200], Step [20/40] Loss: 7.3760
# Epoch [35/200], Step [25/40] Loss: 6.6200
# Epoch [35/200], Step [30/40] Loss: 6.9647
# Epoch [35/200], Step [35/40] Loss: 8.8432
# Epoch [35/200], Step [40/40] Loss: 7.7419
# Epoch [36/200], Step [5/40] Loss: 8.2233
# Epoch [36/200], Step [10/40] Loss: 7.4714
# Epoch [36/200], Step [15/40] Loss: 7.1557
# Epoch [36/200], Step [20/40] Loss: 7.1358
# Epoch [36/200], Step [25/40] Loss: 6.3361
# Epoch [36/200], Step [30/40] Loss: 6.7115
# Epoch [36/200], Step [35/40] Loss: 8.5379
# Epoch [36/200], Step [40/40] Loss: 7.4350
# Epoch [37/200], Step [5/40] Loss: 7.9498
# Epoch [37/200], Step [10/40] Loss: 7.2592
# Epoch [37/200], Step [15/40] Loss: 6.8466
# Epoch [37/200], Step [20/40] Loss: 6.9124
# Epoch [37/200], Step [25/40] Loss: 6.0921
# Epoch [37/200], Step [30/40] Loss: 6.4837
# Epoch [37/200], Step [35/40] Loss: 8.2517
# Epoch [37/200], Step [40/40] Loss: 7.1275
# Epoch [38/200], Step [5/40] Loss: 7.6943
# Epoch [38/200], Step [10/40] Loss: 7.0690
# Epoch [38/200], Step [15/40] Loss: 6.5698
# Epoch [38/200], Step [20/40] Loss: 6.7061
# Epoch [38/200], Step [25/40] Loss: 5.8660
# Epoch [38/200], Step [30/40] Loss: 6.2621
# Epoch [38/200], Step [35/40] Loss: 7.9842
# Epoch [38/200], Step [40/40] Loss: 6.8357
# Epoch [39/200], Step [5/40] Loss: 7.4990
# Epoch [39/200], Step [10/40] Loss: 6.9005
# Epoch [39/200], Step [15/40] Loss: 6.3105
# Epoch [39/200], Step [20/40] Loss: 6.5116
# Epoch [39/200], Step [25/40] Loss: 5.6710
# Epoch [39/200], Step [30/40] Loss: 6.0649
# Epoch [39/200], Step [35/40] Loss: 7.7394
# Epoch [39/200], Step [40/40] Loss: 6.6024
# Epoch [40/200], Step [5/40] Loss: 7.3166
# Epoch [40/200], Step [10/40] Loss: 6.7467
# Epoch [40/200], Step [15/40] Loss: 6.0958
# Epoch [40/200], Step [20/40] Loss: 6.3579
# Epoch [40/200], Step [25/40] Loss: 5.4962
# Epoch [40/200], Step [30/40] Loss: 5.8832
# Epoch [40/200], Step [35/40] Loss: 7.5178
# Epoch [40/200], Step [40/40] Loss: 6.3930
# model: 39
# Epoch [41/200], Step [5/40] Loss: 6.9467
# Epoch [41/200], Step [10/40] Loss: 6.6543
# Epoch [41/200], Step [15/40] Loss: 5.8613
# Epoch [41/200], Step [20/40] Loss: 6.2437
# Epoch [41/200], Step [25/40] Loss: 5.3176
# Epoch [41/200], Step [30/40] Loss: 5.8214
# Epoch [41/200], Step [35/40] Loss: 7.4096
# Epoch [41/200], Step [40/40] Loss: 6.5008
# Epoch [42/200], Step [5/40] Loss: 6.8305
# Epoch [42/200], Step [10/40] Loss: 6.6147
# Epoch [42/200], Step [15/40] Loss: 5.8127
# Epoch [42/200], Step [20/40] Loss: 6.1654
# Epoch [42/200], Step [25/40] Loss: 5.2805
# Epoch [42/200], Step [30/40] Loss: 5.7197
# Epoch [42/200], Step [35/40] Loss: 7.3601
# Epoch [42/200], Step [40/40] Loss: 6.3666
# Epoch [43/200], Step [5/40] Loss: 6.7650
# Epoch [43/200], Step [10/40] Loss: 6.5568
# Epoch [43/200], Step [15/40] Loss: 5.7461
# Epoch [43/200], Step [20/40] Loss: 6.1155
# Epoch [43/200], Step [25/40] Loss: 5.2310
# Epoch [43/200], Step [30/40] Loss: 5.6712
# Epoch [43/200], Step [35/40] Loss: 7.2945
# Epoch [43/200], Step [40/40] Loss: 6.2937
# Epoch [44/200], Step [5/40] Loss: 6.7035
# Epoch [44/200], Step [10/40] Loss: 6.5088
# Epoch [44/200], Step [15/40] Loss: 5.6864
# Epoch [44/200], Step [20/40] Loss: 6.0680
# Epoch [44/200], Step [25/40] Loss: 5.1825
# Epoch [44/200], Step [30/40] Loss: 5.6204
# Epoch [44/200], Step [35/40] Loss: 7.2364
# Epoch [44/200], Step [40/40] Loss: 6.2317
# Epoch [45/200], Step [5/40] Loss: 6.6440
# Epoch [45/200], Step [10/40] Loss: 6.4642
# Epoch [45/200], Step [15/40] Loss: 5.6291
# Epoch [45/200], Step [20/40] Loss: 6.0213
# Epoch [45/200], Step [25/40] Loss: 5.1338
# Epoch [45/200], Step [30/40] Loss: 5.5659
# Epoch [45/200], Step [35/40] Loss: 7.1698
# Epoch [45/200], Step [40/40] Loss: 6.1602
# Epoch [46/200], Step [5/40] Loss: 6.5866
# Epoch [46/200], Step [10/40] Loss: 6.4185
# Epoch [46/200], Step [15/40] Loss: 5.5720
# Epoch [46/200], Step [20/40] Loss: 5.9778
# Epoch [46/200], Step [25/40] Loss: 5.0868
# Epoch [46/200], Step [30/40] Loss: 5.5135
# Epoch [46/200], Step [35/40] Loss: 7.1118
# Epoch [46/200], Step [40/40] Loss: 6.0990
# Epoch [47/200], Step [5/40] Loss: 6.5294
# Epoch [47/200], Step [10/40] Loss: 6.3739
# Epoch [47/200], Step [15/40] Loss: 5.5165
# Epoch [47/200], Step [20/40] Loss: 5.9354
# Epoch [47/200], Step [25/40] Loss: 5.0394
# Epoch [47/200], Step [30/40] Loss: 5.4642
# Epoch [47/200], Step [35/40] Loss: 7.0519
# Epoch [47/200], Step [40/40] Loss: 6.0354
# Epoch [48/200], Step [5/40] Loss: 6.4757
# Epoch [48/200], Step [10/40] Loss: 6.3239
# Epoch [48/200], Step [15/40] Loss: 5.4626
# Epoch [48/200], Step [20/40] Loss: 5.8880
# Epoch [48/200], Step [25/40] Loss: 4.9925
# Epoch [48/200], Step [30/40] Loss: 5.4156
# Epoch [48/200], Step [35/40] Loss: 6.9913
# Epoch [48/200], Step [40/40] Loss: 5.9797
# Epoch [49/200], Step [5/40] Loss: 6.4227
# Epoch [49/200], Step [10/40] Loss: 6.2802
# Epoch [49/200], Step [15/40] Loss: 5.4071
# Epoch [49/200], Step [20/40] Loss: 5.8424
# Epoch [49/200], Step [25/40] Loss: 4.9459
# Epoch [49/200], Step [30/40] Loss: 5.3666
# Epoch [49/200], Step [35/40] Loss: 6.9304
# Epoch [49/200], Step [40/40] Loss: 5.9113
# Epoch [50/200], Step [5/40] Loss: 6.3697
# Epoch [50/200], Step [10/40] Loss: 6.2343
# Epoch [50/200], Step [15/40] Loss: 5.3514
# Epoch [50/200], Step [20/40] Loss: 5.7969
# Epoch [50/200], Step [25/40] Loss: 4.8971
# Epoch [50/200], Step [30/40] Loss: 5.3191
# Epoch [50/200], Step [35/40] Loss: 6.8730
# Epoch [50/200], Step [40/40] Loss: 5.8572
# Epoch [51/200], Step [5/40] Loss: 6.3186
# Epoch [51/200], Step [10/40] Loss: 6.1922
# Epoch [51/200], Step [15/40] Loss: 5.2970
# Epoch [51/200], Step [20/40] Loss: 5.7533
# Epoch [51/200], Step [25/40] Loss: 4.8514
# Epoch [51/200], Step [30/40] Loss: 5.2721
# Epoch [51/200], Step [35/40] Loss: 6.8093
# Epoch [51/200], Step [40/40] Loss: 5.7953
# Epoch [52/200], Step [5/40] Loss: 6.2691
# Epoch [52/200], Step [10/40] Loss: 6.1499
# Epoch [52/200], Step [15/40] Loss: 5.2465
# Epoch [52/200], Step [20/40] Loss: 5.7147
# Epoch [52/200], Step [25/40] Loss: 4.8057
# Epoch [52/200], Step [30/40] Loss: 5.2273
# Epoch [52/200], Step [35/40] Loss: 6.7484
# Epoch [52/200], Step [40/40] Loss: 5.7472
# Epoch [53/200], Step [5/40] Loss: 6.2212
# Epoch [53/200], Step [10/40] Loss: 6.1114
# Epoch [53/200], Step [15/40] Loss: 5.1960
# Epoch [53/200], Step [20/40] Loss: 5.6750
# Epoch [53/200], Step [25/40] Loss: 4.7600
# Epoch [53/200], Step [30/40] Loss: 5.1908
# Epoch [53/200], Step [35/40] Loss: 6.6841
# Epoch [53/200], Step [40/40] Loss: 5.6985
# Epoch [54/200], Step [5/40] Loss: 6.1750
# Epoch [54/200], Step [10/40] Loss: 6.0698
# Epoch [54/200], Step [15/40] Loss: 5.1422
# Epoch [54/200], Step [20/40] Loss: 5.6327
# Epoch [54/200], Step [25/40] Loss: 4.7152
# Epoch [54/200], Step [30/40] Loss: 5.1446
# Epoch [54/200], Step [35/40] Loss: 6.6303
# Epoch [54/200], Step [40/40] Loss: 5.6506
# Epoch [55/200], Step [5/40] Loss: 6.1270
# Epoch [55/200], Step [10/40] Loss: 6.0370
# Epoch [55/200], Step [15/40] Loss: 5.0919
# Epoch [55/200], Step [20/40] Loss: 5.5920
# Epoch [55/200], Step [25/40] Loss: 4.6715
# Epoch [55/200], Step [30/40] Loss: 5.1014
# Epoch [55/200], Step [35/40] Loss: 6.5702
# Epoch [55/200], Step [40/40] Loss: 5.5970
# Epoch [56/200], Step [5/40] Loss: 6.0806
# Epoch [56/200], Step [10/40] Loss: 5.9954
# Epoch [56/200], Step [15/40] Loss: 5.0412
# Epoch [56/200], Step [20/40] Loss: 5.5485
# Epoch [56/200], Step [25/40] Loss: 4.6281
# Epoch [56/200], Step [30/40] Loss: 5.0626
# Epoch [56/200], Step [35/40] Loss: 6.5168
# Epoch [56/200], Step [40/40] Loss: 5.5618
# Epoch [57/200], Step [5/40] Loss: 6.0335
# Epoch [57/200], Step [10/40] Loss: 5.9617
# Epoch [57/200], Step [15/40] Loss: 4.9936
# Epoch [57/200], Step [20/40] Loss: 5.5082
# Epoch [57/200], Step [25/40] Loss: 4.5838
# Epoch [57/200], Step [30/40] Loss: 5.0182
# Epoch [57/200], Step [35/40] Loss: 6.4646
# Epoch [57/200], Step [40/40] Loss: 5.5105
# Epoch [58/200], Step [5/40] Loss: 5.9878
# Epoch [58/200], Step [10/40] Loss: 5.9226
# Epoch [58/200], Step [15/40] Loss: 4.9454
# Epoch [58/200], Step [20/40] Loss: 5.4680
# Epoch [58/200], Step [25/40] Loss: 4.5419
# Epoch [58/200], Step [30/40] Loss: 4.9750
# Epoch [58/200], Step [35/40] Loss: 6.4130
# Epoch [58/200], Step [40/40] Loss: 5.4681
# Epoch [59/200], Step [5/40] Loss: 5.9442
# Epoch [59/200], Step [10/40] Loss: 5.8900
# Epoch [59/200], Step [15/40] Loss: 4.8988
# Epoch [59/200], Step [20/40] Loss: 5.4299
# Epoch [59/200], Step [25/40] Loss: 4.4996
# Epoch [59/200], Step [30/40] Loss: 4.9342
# Epoch [59/200], Step [35/40] Loss: 6.3618
# Epoch [59/200], Step [40/40] Loss: 5.4170
# Epoch [60/200], Step [5/40] Loss: 5.8976
# Epoch [60/200], Step [10/40] Loss: 5.8485
# Epoch [60/200], Step [15/40] Loss: 4.8519
# Epoch [60/200], Step [20/40] Loss: 5.3933
# Epoch [60/200], Step [25/40] Loss: 4.4598
# Epoch [60/200], Step [30/40] Loss: 4.8954
# Epoch [60/200], Step [35/40] Loss: 6.3076
# Epoch [60/200], Step [40/40] Loss: 5.3666
# model: 59
# Epoch [61/200], Step [5/40] Loss: 5.8569
# Epoch [61/200], Step [10/40] Loss: 5.7467
# Epoch [61/200], Step [15/40] Loss: 4.8327
# Epoch [61/200], Step [20/40] Loss: 5.3304
# Epoch [61/200], Step [25/40] Loss: 4.4117
# Epoch [61/200], Step [30/40] Loss: 4.8515
# Epoch [61/200], Step [35/40] Loss: 6.3244
# Epoch [61/200], Step [40/40] Loss: 5.1975
# Epoch [62/200], Step [5/40] Loss: 5.8339
# Epoch [62/200], Step [10/40] Loss: 5.7293
# Epoch [62/200], Step [15/40] Loss: 4.7902
# Epoch [62/200], Step [20/40] Loss: 5.3126
# Epoch [62/200], Step [25/40] Loss: 4.4016
# Epoch [62/200], Step [30/40] Loss: 4.8365
# Epoch [62/200], Step [35/40] Loss: 6.3262
# Epoch [62/200], Step [40/40] Loss: 5.1778
# Epoch [63/200], Step [5/40] Loss: 5.8181
# Epoch [63/200], Step [10/40] Loss: 5.7143
# Epoch [63/200], Step [15/40] Loss: 4.7732
# Epoch [63/200], Step [20/40] Loss: 5.2984
# Epoch [63/200], Step [25/40] Loss: 4.3890
# Epoch [63/200], Step [30/40] Loss: 4.8226
# Epoch [63/200], Step [35/40] Loss: 6.3092
# Epoch [63/200], Step [40/40] Loss: 5.1635
# Epoch [64/200], Step [5/40] Loss: 5.8024
# Epoch [64/200], Step [10/40] Loss: 5.7007
# Epoch [64/200], Step [15/40] Loss: 4.7570
# Epoch [64/200], Step [20/40] Loss: 5.2860
# Epoch [64/200], Step [25/40] Loss: 4.3756
# Epoch [64/200], Step [30/40] Loss: 4.8074
# Epoch [64/200], Step [35/40] Loss: 6.2904
# Epoch [64/200], Step [40/40] Loss: 5.1476
# Epoch [65/200], Step [5/40] Loss: 5.7860
# Epoch [65/200], Step [10/40] Loss: 5.6876
# Epoch [65/200], Step [15/40] Loss: 4.7421
# Epoch [65/200], Step [20/40] Loss: 5.2728
# Epoch [65/200], Step [25/40] Loss: 4.3626
# Epoch [65/200], Step [30/40] Loss: 4.7925
# Epoch [65/200], Step [35/40] Loss: 6.2711
# Epoch [65/200], Step [40/40] Loss: 5.1302
# Epoch [66/200], Step [5/40] Loss: 5.7698
# Epoch [66/200], Step [10/40] Loss: 5.6747
# Epoch [66/200], Step [15/40] Loss: 4.7264
# Epoch [66/200], Step [20/40] Loss: 5.2598
# Epoch [66/200], Step [25/40] Loss: 4.3494
# Epoch [66/200], Step [30/40] Loss: 4.7774
# Epoch [66/200], Step [35/40] Loss: 6.2514
# Epoch [66/200], Step [40/40] Loss: 5.1154
# Epoch [67/200], Step [5/40] Loss: 5.7539
# Epoch [67/200], Step [10/40] Loss: 5.6616
# Epoch [67/200], Step [15/40] Loss: 4.7118
# Epoch [67/200], Step [20/40] Loss: 5.2469
# Epoch [67/200], Step [25/40] Loss: 4.3360
# Epoch [67/200], Step [30/40] Loss: 4.7624
# Epoch [67/200], Step [35/40] Loss: 6.2329
# Epoch [67/200], Step [40/40] Loss: 5.1026
# Epoch [68/200], Step [5/40] Loss: 5.7388
# Epoch [68/200], Step [10/40] Loss: 5.6481
# Epoch [68/200], Step [15/40] Loss: 4.6969
# Epoch [68/200], Step [20/40] Loss: 5.2342
# Epoch [68/200], Step [25/40] Loss: 4.3221
# Epoch [68/200], Step [30/40] Loss: 4.7479
# Epoch [68/200], Step [35/40] Loss: 6.2159
# Epoch [68/200], Step [40/40] Loss: 5.0847
# Epoch [69/200], Step [5/40] Loss: 5.7224
# Epoch [69/200], Step [10/40] Loss: 5.6341
# Epoch [69/200], Step [15/40] Loss: 4.6812
# Epoch [69/200], Step [20/40] Loss: 5.2213
# Epoch [69/200], Step [25/40] Loss: 4.3074
# Epoch [69/200], Step [30/40] Loss: 4.7330
# Epoch [69/200], Step [35/40] Loss: 6.1967
# Epoch [69/200], Step [40/40] Loss: 5.0699
# Epoch [70/200], Step [5/40] Loss: 5.7069
# Epoch [70/200], Step [10/40] Loss: 5.6208
# Epoch [70/200], Step [15/40] Loss: 4.6655
# Epoch [70/200], Step [20/40] Loss: 5.2088
# Epoch [70/200], Step [25/40] Loss: 4.2928
# Epoch [70/200], Step [30/40] Loss: 4.7181
# Epoch [70/200], Step [35/40] Loss: 6.1799
# Epoch [70/200], Step [40/40] Loss: 5.0536
# Epoch [71/200], Step [5/40] Loss: 5.6903
# Epoch [71/200], Step [10/40] Loss: 5.6063
# Epoch [71/200], Step [15/40] Loss: 4.6506
# Epoch [71/200], Step [20/40] Loss: 5.1962
# Epoch [71/200], Step [25/40] Loss: 4.2791
# Epoch [71/200], Step [30/40] Loss: 4.7034
# Epoch [71/200], Step [35/40] Loss: 6.1618
# Epoch [71/200], Step [40/40] Loss: 5.0375
# Epoch [72/200], Step [5/40] Loss: 5.6747
# Epoch [72/200], Step [10/40] Loss: 5.5927
# Epoch [72/200], Step [15/40] Loss: 4.6349
# Epoch [72/200], Step [20/40] Loss: 5.1833
# Epoch [72/200], Step [25/40] Loss: 4.2649
# Epoch [72/200], Step [30/40] Loss: 4.6889
# Epoch [72/200], Step [35/40] Loss: 6.1413
# Epoch [72/200], Step [40/40] Loss: 5.0197
# Epoch [73/200], Step [5/40] Loss: 5.6579
# Epoch [73/200], Step [10/40] Loss: 5.5787
# Epoch [73/200], Step [15/40] Loss: 4.6189
# Epoch [73/200], Step [20/40] Loss: 5.1704
# Epoch [73/200], Step [25/40] Loss: 4.2502
# Epoch [73/200], Step [30/40] Loss: 4.6744
# Epoch [73/200], Step [35/40] Loss: 6.1219
# Epoch [73/200], Step [40/40] Loss: 5.0045
# Epoch [74/200], Step [5/40] Loss: 5.6422
# Epoch [74/200], Step [10/40] Loss: 5.5644
# Epoch [74/200], Step [15/40] Loss: 4.6025
# Epoch [74/200], Step [20/40] Loss: 5.1576
# Epoch [74/200], Step [25/40] Loss: 4.2351
# Epoch [74/200], Step [30/40] Loss: 4.6597
# Epoch [74/200], Step [35/40] Loss: 6.1010
# Epoch [74/200], Step [40/40] Loss: 4.9885
# Epoch [75/200], Step [5/40] Loss: 5.6252
# Epoch [75/200], Step [10/40] Loss: 5.5508
# Epoch [75/200], Step [15/40] Loss: 4.5861
# Epoch [75/200], Step [20/40] Loss: 5.1447
# Epoch [75/200], Step [25/40] Loss: 4.2202
# Epoch [75/200], Step [30/40] Loss: 4.6451
# Epoch [75/200], Step [35/40] Loss: 6.0798
# Epoch [75/200], Step [40/40] Loss: 4.9784
# Epoch [76/200], Step [5/40] Loss: 5.6081
# Epoch [76/200], Step [10/40] Loss: 5.5368
# Epoch [76/200], Step [15/40] Loss: 4.5717
# Epoch [76/200], Step [20/40] Loss: 5.1316
# Epoch [76/200], Step [25/40] Loss: 4.2058
# Epoch [76/200], Step [30/40] Loss: 4.6303
# Epoch [76/200], Step [35/40] Loss: 6.0647
# Epoch [76/200], Step [40/40] Loss: 4.9604
# Epoch [77/200], Step [5/40] Loss: 5.5925
# Epoch [77/200], Step [10/40] Loss: 5.5216
# Epoch [77/200], Step [15/40] Loss: 4.5561
# Epoch [77/200], Step [20/40] Loss: 5.1187
# Epoch [77/200], Step [25/40] Loss: 4.1900
# Epoch [77/200], Step [30/40] Loss: 4.6148
# Epoch [77/200], Step [35/40] Loss: 6.0478
# Epoch [77/200], Step [40/40] Loss: 4.9411
# Epoch [78/200], Step [5/40] Loss: 5.5770
# Epoch [78/200], Step [10/40] Loss: 5.5073
# Epoch [78/200], Step [15/40] Loss: 4.5398
# Epoch [78/200], Step [20/40] Loss: 5.1042
# Epoch [78/200], Step [25/40] Loss: 4.1744
# Epoch [78/200], Step [30/40] Loss: 4.5993
# Epoch [78/200], Step [35/40] Loss: 6.0266
# Epoch [78/200], Step [40/40] Loss: 4.9225
# Epoch [79/200], Step [5/40] Loss: 5.5587
# Epoch [79/200], Step [10/40] Loss: 5.4932
# Epoch [79/200], Step [15/40] Loss: 4.5230
# Epoch [79/200], Step [20/40] Loss: 5.0911
# Epoch [79/200], Step [25/40] Loss: 4.1593
# Epoch [79/200], Step [30/40] Loss: 4.5838
# Epoch [79/200], Step [35/40] Loss: 6.0040
# Epoch [79/200], Step [40/40] Loss: 4.9054
# Epoch [80/200], Step [5/40] Loss: 5.5420
# Epoch [80/200], Step [10/40] Loss: 5.4797
# Epoch [80/200], Step [15/40] Loss: 4.5060
# Epoch [80/200], Step [20/40] Loss: 5.0777
# Epoch [80/200], Step [25/40] Loss: 4.1438
# Epoch [80/200], Step [30/40] Loss: 4.5681
# Epoch [80/200], Step [35/40] Loss: 5.9817
# Epoch [80/200], Step [40/40] Loss: 4.8877
# model: 79
# Epoch [81/200], Step [5/40] Loss: 5.5258
# Epoch [81/200], Step [10/40] Loss: 5.4609
# Epoch [81/200], Step [15/40] Loss: 4.4866
# Epoch [81/200], Step [20/40] Loss: 5.0624
# Epoch [81/200], Step [25/40] Loss: 4.1264
# Epoch [81/200], Step [30/40] Loss: 4.5562
# Epoch [81/200], Step [35/40] Loss: 5.9797
# Epoch [81/200], Step [40/40] Loss: 4.8359
# Epoch [82/200], Step [5/40] Loss: 5.5212
# Epoch [82/200], Step [10/40] Loss: 5.4587
# Epoch [82/200], Step [15/40] Loss: 4.4827
# Epoch [82/200], Step [20/40] Loss: 5.0575
# Epoch [82/200], Step [25/40] Loss: 4.1243
# Epoch [82/200], Step [30/40] Loss: 4.5537
# Epoch [82/200], Step [35/40] Loss: 5.9647
# Epoch [82/200], Step [40/40] Loss: 4.8306
# Epoch [83/200], Step [5/40] Loss: 5.5154
# Epoch [83/200], Step [10/40] Loss: 5.4545
# Epoch [83/200], Step [15/40] Loss: 4.4778
# Epoch [83/200], Step [20/40] Loss: 5.0524
# Epoch [83/200], Step [25/40] Loss: 4.1192
# Epoch [83/200], Step [30/40] Loss: 4.5492
# Epoch [83/200], Step [35/40] Loss: 5.9567
# Epoch [83/200], Step [40/40] Loss: 4.8256
# Epoch [84/200], Step [5/40] Loss: 5.5090
# Epoch [84/200], Step [10/40] Loss: 5.4492
# Epoch [84/200], Step [15/40] Loss: 4.4723
# Epoch [84/200], Step [20/40] Loss: 5.0474
# Epoch [84/200], Step [25/40] Loss: 4.1136
# Epoch [84/200], Step [30/40] Loss: 4.5437
# Epoch [84/200], Step [35/40] Loss: 5.9504
# Epoch [84/200], Step [40/40] Loss: 4.8192
# Epoch [85/200], Step [5/40] Loss: 5.5026
# Epoch [85/200], Step [10/40] Loss: 5.4437
# Epoch [85/200], Step [15/40] Loss: 4.4667
# Epoch [85/200], Step [20/40] Loss: 5.0423
# Epoch [85/200], Step [25/40] Loss: 4.1082
# Epoch [85/200], Step [30/40] Loss: 4.5383
# Epoch [85/200], Step [35/40] Loss: 5.9434
# Epoch [85/200], Step [40/40] Loss: 4.8141
# Epoch [86/200], Step [5/40] Loss: 5.4961
# Epoch [86/200], Step [10/40] Loss: 5.4380
# Epoch [86/200], Step [15/40] Loss: 4.4611
# Epoch [86/200], Step [20/40] Loss: 5.0374
# Epoch [86/200], Step [25/40] Loss: 4.1022
# Epoch [86/200], Step [30/40] Loss: 4.5325
# Epoch [86/200], Step [35/40] Loss: 5.9366
# Epoch [86/200], Step [40/40] Loss: 4.8080
# Epoch [87/200], Step [5/40] Loss: 5.4902
# Epoch [87/200], Step [10/40] Loss: 5.4325
# Epoch [87/200], Step [15/40] Loss: 4.4550
# Epoch [87/200], Step [20/40] Loss: 5.0325
# Epoch [87/200], Step [25/40] Loss: 4.0967
# Epoch [87/200], Step [30/40] Loss: 4.5268
# Epoch [87/200], Step [35/40] Loss: 5.9289
# Epoch [87/200], Step [40/40] Loss: 4.8027
# Epoch [88/200], Step [5/40] Loss: 5.4833
# Epoch [88/200], Step [10/40] Loss: 5.4266
# Epoch [88/200], Step [15/40] Loss: 4.4490
# Epoch [88/200], Step [20/40] Loss: 5.0275
# Epoch [88/200], Step [25/40] Loss: 4.0910
# Epoch [88/200], Step [30/40] Loss: 4.5209
# Epoch [88/200], Step [35/40] Loss: 5.9210
# Epoch [88/200], Step [40/40] Loss: 4.7973
# Epoch [89/200], Step [5/40] Loss: 5.4771
# Epoch [89/200], Step [10/40] Loss: 5.4210
# Epoch [89/200], Step [15/40] Loss: 4.4426
# Epoch [89/200], Step [20/40] Loss: 5.0223
# Epoch [89/200], Step [25/40] Loss: 4.0851
# Epoch [89/200], Step [30/40] Loss: 4.5145
# Epoch [89/200], Step [35/40] Loss: 5.9144
# Epoch [89/200], Step [40/40] Loss: 4.7915
# Epoch [90/200], Step [5/40] Loss: 5.4703
# Epoch [90/200], Step [10/40] Loss: 5.4154
# Epoch [90/200], Step [15/40] Loss: 4.4355
# Epoch [90/200], Step [20/40] Loss: 5.0171
# Epoch [90/200], Step [25/40] Loss: 4.0794
# Epoch [90/200], Step [30/40] Loss: 4.5085
# Epoch [90/200], Step [35/40] Loss: 5.9069
# Epoch [90/200], Step [40/40] Loss: 4.7845
# Epoch [91/200], Step [5/40] Loss: 5.4641
# Epoch [91/200], Step [10/40] Loss: 5.4095
# Epoch [91/200], Step [15/40] Loss: 4.4292
# Epoch [91/200], Step [20/40] Loss: 5.0117
# Epoch [91/200], Step [25/40] Loss: 4.0735
# Epoch [91/200], Step [30/40] Loss: 4.5025
# Epoch [91/200], Step [35/40] Loss: 5.8993
# Epoch [91/200], Step [40/40] Loss: 4.7789
# Epoch [92/200], Step [5/40] Loss: 5.4569
# Epoch [92/200], Step [10/40] Loss: 5.4037
# Epoch [92/200], Step [15/40] Loss: 4.4227
# Epoch [92/200], Step [20/40] Loss: 5.0062
# Epoch [92/200], Step [25/40] Loss: 4.0674
# Epoch [92/200], Step [30/40] Loss: 4.4964
# Epoch [92/200], Step [35/40] Loss: 5.8919
# Epoch [92/200], Step [40/40] Loss: 4.7722
# Epoch [93/200], Step [5/40] Loss: 5.4505
# Epoch [93/200], Step [10/40] Loss: 5.3978
# Epoch [93/200], Step [15/40] Loss: 4.4158
# Epoch [93/200], Step [20/40] Loss: 5.0006
# Epoch [93/200], Step [25/40] Loss: 4.0616
# Epoch [93/200], Step [30/40] Loss: 4.4902
# Epoch [93/200], Step [35/40] Loss: 5.8850
# Epoch [93/200], Step [40/40] Loss: 4.7647
# Epoch [94/200], Step [5/40] Loss: 5.4436
# Epoch [94/200], Step [10/40] Loss: 5.3925
# Epoch [94/200], Step [15/40] Loss: 4.4090
# Epoch [94/200], Step [20/40] Loss: 4.9951
# Epoch [94/200], Step [25/40] Loss: 4.0554
# Epoch [94/200], Step [30/40] Loss: 4.4840
# Epoch [94/200], Step [35/40] Loss: 5.8765
# Epoch [94/200], Step [40/40] Loss: 4.7585
# Epoch [95/200], Step [5/40] Loss: 5.4367
# Epoch [95/200], Step [10/40] Loss: 5.3866
# Epoch [95/200], Step [15/40] Loss: 4.4022
# Epoch [95/200], Step [20/40] Loss: 4.9897
# Epoch [95/200], Step [25/40] Loss: 4.0491
# Epoch [95/200], Step [30/40] Loss: 4.4779
# Epoch [95/200], Step [35/40] Loss: 5.8688
# Epoch [95/200], Step [40/40] Loss: 4.7507
# Epoch [96/200], Step [5/40] Loss: 5.4296
# Epoch [96/200], Step [10/40] Loss: 5.3805
# Epoch [96/200], Step [15/40] Loss: 4.3950
# Epoch [96/200], Step [20/40] Loss: 4.9842
# Epoch [96/200], Step [25/40] Loss: 4.0430
# Epoch [96/200], Step [30/40] Loss: 4.4717
# Epoch [96/200], Step [35/40] Loss: 5.8597
# Epoch [96/200], Step [40/40] Loss: 4.7436
# Epoch [97/200], Step [5/40] Loss: 5.4223
# Epoch [97/200], Step [10/40] Loss: 5.3745
# Epoch [97/200], Step [15/40] Loss: 4.3884
# Epoch [97/200], Step [20/40] Loss: 4.9782
# Epoch [97/200], Step [25/40] Loss: 4.0365
# Epoch [97/200], Step [30/40] Loss: 4.4654
# Epoch [97/200], Step [35/40] Loss: 5.8516
# Epoch [97/200], Step [40/40] Loss: 4.7367
# Epoch [98/200], Step [5/40] Loss: 5.4155
# Epoch [98/200], Step [10/40] Loss: 5.3686
# Epoch [98/200], Step [15/40] Loss: 4.3813
# Epoch [98/200], Step [20/40] Loss: 4.9723
# Epoch [98/200], Step [25/40] Loss: 4.0302
# Epoch [98/200], Step [30/40] Loss: 4.4592
# Epoch [98/200], Step [35/40] Loss: 5.8431
# Epoch [98/200], Step [40/40] Loss: 4.7290
# Epoch [99/200], Step [5/40] Loss: 5.4086
# Epoch [99/200], Step [10/40] Loss: 5.3626
# Epoch [99/200], Step [15/40] Loss: 4.3739
# Epoch [99/200], Step [20/40] Loss: 4.9666
# Epoch [99/200], Step [25/40] Loss: 4.0235
# Epoch [99/200], Step [30/40] Loss: 4.4527
# Epoch [99/200], Step [35/40] Loss: 5.8344
# Epoch [99/200], Step [40/40] Loss: 4.7226
# Epoch [100/200], Step [5/40] Loss: 5.4009
# Epoch [100/200], Step [10/40] Loss: 5.3567
# Epoch [100/200], Step [15/40] Loss: 4.3669
# Epoch [100/200], Step [20/40] Loss: 4.9607
# Epoch [100/200], Step [25/40] Loss: 4.0169
# Epoch [100/200], Step [30/40] Loss: 4.4462
# Epoch [100/200], Step [35/40] Loss: 5.8254
# Epoch [100/200], Step [40/40] Loss: 4.7168
# model: 99
# Epoch [101/200], Step [5/40] Loss: 5.3927
# Epoch [101/200], Step [10/40] Loss: 5.3484
# Epoch [101/200], Step [15/40] Loss: 4.3606
# Epoch [101/200], Step [20/40] Loss: 4.9543
# Epoch [101/200], Step [25/40] Loss: 4.0085
# Epoch [101/200], Step [30/40] Loss: 4.4440
# Epoch [101/200], Step [35/40] Loss: 5.8084
# Epoch [101/200], Step [40/40] Loss: 4.7129
# Epoch [102/200], Step [5/40] Loss: 5.3901
# Epoch [102/200], Step [10/40] Loss: 5.3475
# Epoch [102/200], Step [15/40] Loss: 4.3592
# Epoch [102/200], Step [20/40] Loss: 4.9523
# Epoch [102/200], Step [25/40] Loss: 4.0065
# Epoch [102/200], Step [30/40] Loss: 4.4416
# Epoch [102/200], Step [35/40] Loss: 5.8057
# Epoch [102/200], Step [40/40] Loss: 4.7105
# Epoch [103/200], Step [5/40] Loss: 5.3871
# Epoch [103/200], Step [10/40] Loss: 5.3453
# Epoch [103/200], Step [15/40] Loss: 4.3566
# Epoch [103/200], Step [20/40] Loss: 4.9501
# Epoch [103/200], Step [25/40] Loss: 4.0042
# Epoch [103/200], Step [30/40] Loss: 4.4392
# Epoch [103/200], Step [35/40] Loss: 5.8026
# Epoch [103/200], Step [40/40] Loss: 4.7079
# Epoch [104/200], Step [5/40] Loss: 5.3845
# Epoch [104/200], Step [10/40] Loss: 5.3432
# Epoch [104/200], Step [15/40] Loss: 4.3542
# Epoch [104/200], Step [20/40] Loss: 4.9480
# Epoch [104/200], Step [25/40] Loss: 4.0018
# Epoch [104/200], Step [30/40] Loss: 4.4365
# Epoch [104/200], Step [35/40] Loss: 5.7999
# Epoch [104/200], Step [40/40] Loss: 4.7054
# Epoch [105/200], Step [5/40] Loss: 5.3818
# Epoch [105/200], Step [10/40] Loss: 5.3409
# Epoch [105/200], Step [15/40] Loss: 4.3514
# Epoch [105/200], Step [20/40] Loss: 4.9459
# Epoch [105/200], Step [25/40] Loss: 3.9993
# Epoch [105/200], Step [30/40] Loss: 4.4339
# Epoch [105/200], Step [35/40] Loss: 5.7970
# Epoch [105/200], Step [40/40] Loss: 4.7025
# Epoch [106/200], Step [5/40] Loss: 5.3793
# Epoch [106/200], Step [10/40] Loss: 5.3385
# Epoch [106/200], Step [15/40] Loss: 4.3486
# Epoch [106/200], Step [20/40] Loss: 4.9438
# Epoch [106/200], Step [25/40] Loss: 3.9969
# Epoch [106/200], Step [30/40] Loss: 4.4313
# Epoch [106/200], Step [35/40] Loss: 5.7941
# Epoch [106/200], Step [40/40] Loss: 4.6996
# Epoch [107/200], Step [5/40] Loss: 5.3764
# Epoch [107/200], Step [10/40] Loss: 5.3361
# Epoch [107/200], Step [15/40] Loss: 4.3461
# Epoch [107/200], Step [20/40] Loss: 4.9416
# Epoch [107/200], Step [25/40] Loss: 3.9943
# Epoch [107/200], Step [30/40] Loss: 4.4287
# Epoch [107/200], Step [35/40] Loss: 5.7910
# Epoch [107/200], Step [40/40] Loss: 4.6967
# Epoch [108/200], Step [5/40] Loss: 5.3738
# Epoch [108/200], Step [10/40] Loss: 5.3336
# Epoch [108/200], Step [15/40] Loss: 4.3433
# Epoch [108/200], Step [20/40] Loss: 4.9392
# Epoch [108/200], Step [25/40] Loss: 3.9918
# Epoch [108/200], Step [30/40] Loss: 4.4262
# Epoch [108/200], Step [35/40] Loss: 5.7879
# Epoch [108/200], Step [40/40] Loss: 4.6938
# Epoch [109/200], Step [5/40] Loss: 5.3709
# Epoch [109/200], Step [10/40] Loss: 5.3313
# Epoch [109/200], Step [15/40] Loss: 4.3407
# Epoch [109/200], Step [20/40] Loss: 4.9370
# Epoch [109/200], Step [25/40] Loss: 3.9892
# Epoch [109/200], Step [30/40] Loss: 4.4237
# Epoch [109/200], Step [35/40] Loss: 5.7843
# Epoch [109/200], Step [40/40] Loss: 4.6912
# Epoch [110/200], Step [5/40] Loss: 5.3679
# Epoch [110/200], Step [10/40] Loss: 5.3289
# Epoch [110/200], Step [15/40] Loss: 4.3380
# Epoch [110/200], Step [20/40] Loss: 4.9346
# Epoch [110/200], Step [25/40] Loss: 3.9866
# Epoch [110/200], Step [30/40] Loss: 4.4211
# Epoch [110/200], Step [35/40] Loss: 5.7807
# Epoch [110/200], Step [40/40] Loss: 4.6887
# Epoch [111/200], Step [5/40] Loss: 5.3651
# Epoch [111/200], Step [10/40] Loss: 5.3265
# Epoch [111/200], Step [15/40] Loss: 4.3353
# Epoch [111/200], Step [20/40] Loss: 4.9324
# Epoch [111/200], Step [25/40] Loss: 3.9839
# Epoch [111/200], Step [30/40] Loss: 4.4182
# Epoch [111/200], Step [35/40] Loss: 5.7775
# Epoch [111/200], Step [40/40] Loss: 4.6859
# Epoch [112/200], Step [5/40] Loss: 5.3621
# Epoch [112/200], Step [10/40] Loss: 5.3239
# Epoch [112/200], Step [15/40] Loss: 4.3324
# Epoch [112/200], Step [20/40] Loss: 4.9299
# Epoch [112/200], Step [25/40] Loss: 3.9810
# Epoch [112/200], Step [30/40] Loss: 4.4154
# Epoch [112/200], Step [35/40] Loss: 5.7743
# Epoch [112/200], Step [40/40] Loss: 4.6829
# Epoch [113/200], Step [5/40] Loss: 5.3591
# Epoch [113/200], Step [10/40] Loss: 5.3213
# Epoch [113/200], Step [15/40] Loss: 4.3293
# Epoch [113/200], Step [20/40] Loss: 4.9276
# Epoch [113/200], Step [25/40] Loss: 3.9782
# Epoch [113/200], Step [30/40] Loss: 4.4125
# Epoch [113/200], Step [35/40] Loss: 5.7711
# Epoch [113/200], Step [40/40] Loss: 4.6799
# Epoch [114/200], Step [5/40] Loss: 5.3561
# Epoch [114/200], Step [10/40] Loss: 5.3188
# Epoch [114/200], Step [15/40] Loss: 4.3262
# Epoch [114/200], Step [20/40] Loss: 4.9249
# Epoch [114/200], Step [25/40] Loss: 3.9754
# Epoch [114/200], Step [30/40] Loss: 4.4096
# Epoch [114/200], Step [35/40] Loss: 5.7680
# Epoch [114/200], Step [40/40] Loss: 4.6763
# Epoch [115/200], Step [5/40] Loss: 5.3530
# Epoch [115/200], Step [10/40] Loss: 5.3161
# Epoch [115/200], Step [15/40] Loss: 4.3229
# Epoch [115/200], Step [20/40] Loss: 4.9224
# Epoch [115/200], Step [25/40] Loss: 3.9728
# Epoch [115/200], Step [30/40] Loss: 4.4067
# Epoch [115/200], Step [35/40] Loss: 5.7645
# Epoch [115/200], Step [40/40] Loss: 4.6729
# Epoch [116/200], Step [5/40] Loss: 5.3501
# Epoch [116/200], Step [10/40] Loss: 5.3136
# Epoch [116/200], Step [15/40] Loss: 4.3198
# Epoch [116/200], Step [20/40] Loss: 4.9197
# Epoch [116/200], Step [25/40] Loss: 3.9699
# Epoch [116/200], Step [30/40] Loss: 4.4039
# Epoch [116/200], Step [35/40] Loss: 5.7608
# Epoch [116/200], Step [40/40] Loss: 4.6698
# Epoch [117/200], Step [5/40] Loss: 5.3468
# Epoch [117/200], Step [10/40] Loss: 5.3109
# Epoch [117/200], Step [15/40] Loss: 4.3166
# Epoch [117/200], Step [20/40] Loss: 4.9170
# Epoch [117/200], Step [25/40] Loss: 3.9670
# Epoch [117/200], Step [30/40] Loss: 4.4010
# Epoch [117/200], Step [35/40] Loss: 5.7571
# Epoch [117/200], Step [40/40] Loss: 4.6665
# Epoch [118/200], Step [5/40] Loss: 5.3435
# Epoch [118/200], Step [10/40] Loss: 5.3081
# Epoch [118/200], Step [15/40] Loss: 4.3134
# Epoch [118/200], Step [20/40] Loss: 4.9145
# Epoch [118/200], Step [25/40] Loss: 3.9640
# Epoch [118/200], Step [30/40] Loss: 4.3981
# Epoch [118/200], Step [35/40] Loss: 5.7531
# Epoch [118/200], Step [40/40] Loss: 4.6636
# Epoch [119/200], Step [5/40] Loss: 5.3402
# Epoch [119/200], Step [10/40] Loss: 5.3054
# Epoch [119/200], Step [15/40] Loss: 4.3102
# Epoch [119/200], Step [20/40] Loss: 4.9116
# Epoch [119/200], Step [25/40] Loss: 3.9611
# Epoch [119/200], Step [30/40] Loss: 4.3951
# Epoch [119/200], Step [35/40] Loss: 5.7492
# Epoch [119/200], Step [40/40] Loss: 4.6601
# Epoch [120/200], Step [5/40] Loss: 5.3370
# Epoch [120/200], Step [10/40] Loss: 5.3027
# Epoch [120/200], Step [15/40] Loss: 4.3069
# Epoch [120/200], Step [20/40] Loss: 4.9090
# Epoch [120/200], Step [25/40] Loss: 3.9579
# Epoch [120/200], Step [30/40] Loss: 4.3922
# Epoch [120/200], Step [35/40] Loss: 5.7446
# Epoch [120/200], Step [40/40] Loss: 4.6573
# model: 119
# Epoch [121/200], Step [5/40] Loss: 5.3333
# Epoch [121/200], Step [10/40] Loss: 5.2987
# Epoch [121/200], Step [15/40] Loss: 4.3034
# Epoch [121/200], Step [20/40] Loss: 4.9064
# Epoch [121/200], Step [25/40] Loss: 3.9542
# Epoch [121/200], Step [30/40] Loss: 4.3898
# Epoch [121/200], Step [35/40] Loss: 5.7398
# Epoch [121/200], Step [40/40] Loss: 4.6553
# Epoch [122/200], Step [5/40] Loss: 5.3319
# Epoch [122/200], Step [10/40] Loss: 5.2980
# Epoch [122/200], Step [15/40] Loss: 4.3025
# Epoch [122/200], Step [20/40] Loss: 4.9053
# Epoch [122/200], Step [25/40] Loss: 3.9533
# Epoch [122/200], Step [30/40] Loss: 4.3887
# Epoch [122/200], Step [35/40] Loss: 5.7385
# Epoch [122/200], Step [40/40] Loss: 4.6541
# Epoch [123/200], Step [5/40] Loss: 5.3307
# Epoch [123/200], Step [10/40] Loss: 5.2970
# Epoch [123/200], Step [15/40] Loss: 4.3014
# Epoch [123/200], Step [20/40] Loss: 4.9043
# Epoch [123/200], Step [25/40] Loss: 3.9522
# Epoch [123/200], Step [30/40] Loss: 4.3876
# Epoch [123/200], Step [35/40] Loss: 5.7373
# Epoch [123/200], Step [40/40] Loss: 4.6527
# Epoch [124/200], Step [5/40] Loss: 5.3295
# Epoch [124/200], Step [10/40] Loss: 5.2960
# Epoch [124/200], Step [15/40] Loss: 4.3002
# Epoch [124/200], Step [20/40] Loss: 4.9034
# Epoch [124/200], Step [25/40] Loss: 3.9512
# Epoch [124/200], Step [30/40] Loss: 4.3865
# Epoch [124/200], Step [35/40] Loss: 5.7360
# Epoch [124/200], Step [40/40] Loss: 4.6515
# Epoch [125/200], Step [5/40] Loss: 5.3283
# Epoch [125/200], Step [10/40] Loss: 5.2950
# Epoch [125/200], Step [15/40] Loss: 4.2990
# Epoch [125/200], Step [20/40] Loss: 4.9024
# Epoch [125/200], Step [25/40] Loss: 3.9501
# Epoch [125/200], Step [30/40] Loss: 4.3854
# Epoch [125/200], Step [35/40] Loss: 5.7346
# Epoch [125/200], Step [40/40] Loss: 4.6503
# Epoch [126/200], Step [5/40] Loss: 5.3270
# Epoch [126/200], Step [10/40] Loss: 5.2939
# Epoch [126/200], Step [15/40] Loss: 4.2977
# Epoch [126/200], Step [20/40] Loss: 4.9013
# Epoch [126/200], Step [25/40] Loss: 3.9490
# Epoch [126/200], Step [30/40] Loss: 4.3843
# Epoch [126/200], Step [35/40] Loss: 5.7331
# Epoch [126/200], Step [40/40] Loss: 4.6490
# Epoch [127/200], Step [5/40] Loss: 5.3257
# Epoch [127/200], Step [10/40] Loss: 5.2929
# Epoch [127/200], Step [15/40] Loss: 4.2964
# Epoch [127/200], Step [20/40] Loss: 4.9003
# Epoch [127/200], Step [25/40] Loss: 3.9479
# Epoch [127/200], Step [30/40] Loss: 4.3832
# Epoch [127/200], Step [35/40] Loss: 5.7315
# Epoch [127/200], Step [40/40] Loss: 4.6478
# Epoch [128/200], Step [5/40] Loss: 5.3245
# Epoch [128/200], Step [10/40] Loss: 5.2919
# Epoch [128/200], Step [15/40] Loss: 4.2952
# Epoch [128/200], Step [20/40] Loss: 4.8992
# Epoch [128/200], Step [25/40] Loss: 3.9468
# Epoch [128/200], Step [30/40] Loss: 4.3820
# Epoch [128/200], Step [35/40] Loss: 5.7301
# Epoch [128/200], Step [40/40] Loss: 4.6465
# Epoch [129/200], Step [5/40] Loss: 5.3232
# Epoch [129/200], Step [10/40] Loss: 5.2908
# Epoch [129/200], Step [15/40] Loss: 4.2938
# Epoch [129/200], Step [20/40] Loss: 4.8982
# Epoch [129/200], Step [25/40] Loss: 3.9456
# Epoch [129/200], Step [30/40] Loss: 4.3808
# Epoch [129/200], Step [35/40] Loss: 5.7287
# Epoch [129/200], Step [40/40] Loss: 4.6452
# Epoch [130/200], Step [5/40] Loss: 5.3218
# Epoch [130/200], Step [10/40] Loss: 5.2896
# Epoch [130/200], Step [15/40] Loss: 4.2925
# Epoch [130/200], Step [20/40] Loss: 4.8971
# Epoch [130/200], Step [25/40] Loss: 3.9444
# Epoch [130/200], Step [30/40] Loss: 4.3796
# Epoch [130/200], Step [35/40] Loss: 5.7271
# Epoch [130/200], Step [40/40] Loss: 4.6438
# Epoch [131/200], Step [5/40] Loss: 5.3206
# Epoch [131/200], Step [10/40] Loss: 5.2885
# Epoch [131/200], Step [15/40] Loss: 4.2912
# Epoch [131/200], Step [20/40] Loss: 4.8960
# Epoch [131/200], Step [25/40] Loss: 3.9432
# Epoch [131/200], Step [30/40] Loss: 4.3784
# Epoch [131/200], Step [35/40] Loss: 5.7255
# Epoch [131/200], Step [40/40] Loss: 4.6425
# Epoch [132/200], Step [5/40] Loss: 5.3192
# Epoch [132/200], Step [10/40] Loss: 5.2874
# Epoch [132/200], Step [15/40] Loss: 4.2898
# Epoch [132/200], Step [20/40] Loss: 4.8948
# Epoch [132/200], Step [25/40] Loss: 3.9420
# Epoch [132/200], Step [30/40] Loss: 4.3771
# Epoch [132/200], Step [35/40] Loss: 5.7240
# Epoch [132/200], Step [40/40] Loss: 4.6411
# Epoch [133/200], Step [5/40] Loss: 5.3178
# Epoch [133/200], Step [10/40] Loss: 5.2863
# Epoch [133/200], Step [15/40] Loss: 4.2884
# Epoch [133/200], Step [20/40] Loss: 4.8937
# Epoch [133/200], Step [25/40] Loss: 3.9407
# Epoch [133/200], Step [30/40] Loss: 4.3759
# Epoch [133/200], Step [35/40] Loss: 5.7222
# Epoch [133/200], Step [40/40] Loss: 4.6398
# Epoch [134/200], Step [5/40] Loss: 5.3164
# Epoch [134/200], Step [10/40] Loss: 5.2851
# Epoch [134/200], Step [15/40] Loss: 4.2870
# Epoch [134/200], Step [20/40] Loss: 4.8925
# Epoch [134/200], Step [25/40] Loss: 3.9395
# Epoch [134/200], Step [30/40] Loss: 4.3747
# Epoch [134/200], Step [35/40] Loss: 5.7206
# Epoch [134/200], Step [40/40] Loss: 4.6384
# Epoch [135/200], Step [5/40] Loss: 5.3148
# Epoch [135/200], Step [10/40] Loss: 5.2838
# Epoch [135/200], Step [15/40] Loss: 4.2855
# Epoch [135/200], Step [20/40] Loss: 4.8913
# Epoch [135/200], Step [25/40] Loss: 3.9381
# Epoch [135/200], Step [30/40] Loss: 4.3733
# Epoch [135/200], Step [35/40] Loss: 5.7189
# Epoch [135/200], Step [40/40] Loss: 4.6369
# Epoch [136/200], Step [5/40] Loss: 5.3134
# Epoch [136/200], Step [10/40] Loss: 5.2827
# Epoch [136/200], Step [15/40] Loss: 4.2839
# Epoch [136/200], Step [20/40] Loss: 4.8902
# Epoch [136/200], Step [25/40] Loss: 3.9368
# Epoch [136/200], Step [30/40] Loss: 4.3720
# Epoch [136/200], Step [35/40] Loss: 5.7172
# Epoch [136/200], Step [40/40] Loss: 4.6354
# Epoch [137/200], Step [5/40] Loss: 5.3119
# Epoch [137/200], Step [10/40] Loss: 5.2814
# Epoch [137/200], Step [15/40] Loss: 4.2825
# Epoch [137/200], Step [20/40] Loss: 4.8889
# Epoch [137/200], Step [25/40] Loss: 3.9355
# Epoch [137/200], Step [30/40] Loss: 4.3707
# Epoch [137/200], Step [35/40] Loss: 5.7155
# Epoch [137/200], Step [40/40] Loss: 4.6339
# Epoch [138/200], Step [5/40] Loss: 5.3104
# Epoch [138/200], Step [10/40] Loss: 5.2800
# Epoch [138/200], Step [15/40] Loss: 4.2810
# Epoch [138/200], Step [20/40] Loss: 4.8877
# Epoch [138/200], Step [25/40] Loss: 3.9341
# Epoch [138/200], Step [30/40] Loss: 4.3693
# Epoch [138/200], Step [35/40] Loss: 5.7137
# Epoch [138/200], Step [40/40] Loss: 4.6323
# Epoch [139/200], Step [5/40] Loss: 5.3089
# Epoch [139/200], Step [10/40] Loss: 5.2788
# Epoch [139/200], Step [15/40] Loss: 4.2794
# Epoch [139/200], Step [20/40] Loss: 4.8864
# Epoch [139/200], Step [25/40] Loss: 3.9327
# Epoch [139/200], Step [30/40] Loss: 4.3679
# Epoch [139/200], Step [35/40] Loss: 5.7119
# Epoch [139/200], Step [40/40] Loss: 4.6308
# Epoch [140/200], Step [5/40] Loss: 5.3073
# Epoch [140/200], Step [10/40] Loss: 5.2776
# Epoch [140/200], Step [15/40] Loss: 4.2779
# Epoch [140/200], Step [20/40] Loss: 4.8851
# Epoch [140/200], Step [25/40] Loss: 3.9313
# Epoch [140/200], Step [30/40] Loss: 4.3666
# Epoch [140/200], Step [35/40] Loss: 5.7100
# Epoch [140/200], Step [40/40] Loss: 4.6294
# model: 139
# Epoch [141/200], Step [5/40] Loss: 5.3055
# Epoch [141/200], Step [10/40] Loss: 5.2758
# Epoch [141/200], Step [15/40] Loss: 4.2762
# Epoch [141/200], Step [20/40] Loss: 4.8838
# Epoch [141/200], Step [25/40] Loss: 3.9296
# Epoch [141/200], Step [30/40] Loss: 4.3655
# Epoch [141/200], Step [35/40] Loss: 5.7078
# ...
# Epoch [158/200], Step [10/40] Loss: 5.2669
# Epoch [158/200], Step [15/40] Loss: 4.2656
# Epoch [158/200], Step [20/40] Loss: 4.8752
# Epoch [158/200], Step [25/40] Loss: 3.9198
# Epoch [158/200], Step [30/40] Loss: 4.3559
# Epoch [158/200], Step [35/40] Loss: 5.6954
# Epoch [158/200], Step [40/40] Loss: 4.6178
# Epoch [159/200], Step [5/40] Loss: 5.2942
# Epoch [159/200], Step [10/40] Loss: 5.2662
# Epoch [159/200], Step [15/40] Loss: 4.2649
# Epoch [159/200], Step [20/40] Loss: 4.8746
# Epoch [159/200], Step [25/40] Loss: 3.9192
# Epoch [159/200], Step [30/40] Loss: 4.3552
# Epoch [159/200], Step [35/40] Loss: 5.6946
# Epoch [159/200], Step [40/40] Loss: 4.6171
# Epoch [160/200], Step [5/40] Loss: 5.2935
# Epoch [160/200], Step [10/40] Loss: 5.2656
# Epoch [160/200], Step [15/40] Loss: 4.2641
# Epoch [160/200], Step [20/40] Loss: 4.8740
# Epoch [160/200], Step [25/40] Loss: 3.9185
# Epoch [160/200], Step [30/40] Loss: 4.3546
# Epoch [160/200], Step [35/40] Loss: 5.6937
# Epoch [160/200], Step [40/40] Loss: 4.6164
# model: 159
# Epoch [161/200], Step [5/40] Loss: 5.2926
# Epoch [161/200], Step [10/40] Loss: 5.2648
# Epoch [161/200], Step [15/40] Loss: 4.2632
# Epoch [161/200], Step [20/40] Loss: 4.8733
# Epoch [161/200], Step [25/40] Loss: 3.9177
# Epoch [161/200], Step [30/40] Loss: 4.3540
# Epoch [161/200], Step [35/40] Loss: 5.6928
# Epoch [161/200], Step [40/40] Loss: 4.6160
# Epoch [162/200], Step [5/40] Loss: 5.2924
# Epoch [162/200], Step [10/40] Loss: 5.2646
# Epoch [162/200], Step [15/40] Loss: 4.2630
# Epoch [162/200], Step [20/40] Loss: 4.8731
# Epoch [162/200], Step [25/40] Loss: 3.9174
# Epoch [162/200], Step [30/40] Loss: 4.3538
# Epoch [162/200], Step [35/40] Loss: 5.6925
# Epoch [162/200], Step [40/40] Loss: 4.6157
# Epoch [163/200], Step [5/40] Loss: 5.2921
# Epoch [163/200], Step [10/40] Loss: 5.2644
# Epoch [163/200], Step [15/40] Loss: 4.2628
# Epoch [163/200], Step [20/40] Loss: 4.8729
# Epoch [163/200], Step [25/40] Loss: 3.9172
# Epoch [163/200], Step [30/40] Loss: 4.3535
# Epoch [163/200], Step [35/40] Loss: 5.6922
# Epoch [163/200], Step [40/40] Loss: 4.6155
# Epoch [164/200], Step [5/40] Loss: 5.2919
# Epoch [164/200], Step [10/40] Loss: 5.2641
# Epoch [164/200], Step [15/40] Loss: 4.2625
# Epoch [164/200], Step [20/40] Loss: 4.8727
# Epoch [164/200], Step [25/40] Loss: 3.9170
# Epoch [164/200], Step [30/40] Loss: 4.3533
# Epoch [164/200], Step [35/40] Loss: 5.6919
# Epoch [164/200], Step [40/40] Loss: 4.6152
# Epoch [165/200], Step [5/40] Loss: 5.2916
# Epoch [165/200], Step [10/40] Loss: 5.2639
# Epoch [165/200], Step [15/40] Loss: 4.2622
# Epoch [165/200], Step [20/40] Loss: 4.8725
# Epoch [165/200], Step [25/40] Loss: 3.9167
# Epoch [165/200], Step [30/40] Loss: 4.3531
# Epoch [165/200], Step [35/40] Loss: 5.6916
# Epoch [165/200], Step [40/40] Loss: 4.6149
# Epoch [166/200], Step [5/40] Loss: 5.2913
# Epoch [166/200], Step [10/40] Loss: 5.2637
# Epoch [166/200], Step [15/40] Loss: 4.2620
# Epoch [166/200], Step [20/40] Loss: 4.8723
# Epoch [166/200], Step [25/40] Loss: 3.9165
# Epoch [166/200], Step [30/40] Loss: 4.3528
# Epoch [166/200], Step [35/40] Loss: 5.6913
# Epoch [166/200], Step [40/40] Loss: 4.6147
# Epoch [167/200], Step [5/40] Loss: 5.2910
# Epoch [167/200], Step [10/40] Loss: 5.2634
# Epoch [167/200], Step [15/40] Loss: 4.2617
# Epoch [167/200], Step [20/40] Loss: 4.8720
# Epoch [167/200], Step [25/40] Loss: 3.9162
# Epoch [167/200], Step [30/40] Loss: 4.3526
# Epoch [167/200], Step [35/40] Loss: 5.6910
# Epoch [167/200], Step [40/40] Loss: 4.6144
# Epoch [168/200], Step [5/40] Loss: 5.2908
# Epoch [168/200], Step [10/40] Loss: 5.2632
# Epoch [168/200], Step [15/40] Loss: 4.2614
# Epoch [168/200], Step [20/40] Loss: 4.8718
# Epoch [168/200], Step [25/40] Loss: 3.9160
# Epoch [168/200], Step [30/40] Loss: 4.3523
# Epoch [168/200], Step [35/40] Loss: 5.6906
# Epoch [168/200], Step [40/40] Loss: 4.6141
# Epoch [169/200], Step [5/40] Loss: 5.2905
# Epoch [169/200], Step [10/40] Loss: 5.2630
# Epoch [169/200], Step [15/40] Loss: 4.2611
# Epoch [169/200], Step [20/40] Loss: 4.8716
# Epoch [169/200], Step [25/40] Loss: 3.9157
# Epoch [169/200], Step [30/40] Loss: 4.3521
# Epoch [169/200], Step [35/40] Loss: 5.6903
# Epoch [169/200], Step [40/40] Loss: 4.6138
# Epoch [170/200], Step [5/40] Loss: 5.2902
# Epoch [170/200], Step [10/40] Loss: 5.2627
# Epoch [170/200], Step [15/40] Loss: 4.2608
# Epoch [170/200], Step [20/40] Loss: 4.8713
# Epoch [170/200], Step [25/40] Loss: 3.9154
# Epoch [170/200], Step [30/40] Loss: 4.3518
# Epoch [170/200], Step [35/40] Loss: 5.6900
# Epoch [170/200], Step [40/40] Loss: 4.6135
# Epoch [171/200], Step [5/40] Loss: 5.2899
# Epoch [171/200], Step [10/40] Loss: 5.2624
# Epoch [171/200], Step [15/40] Loss: 4.2605
# Epoch [171/200], Step [20/40] Loss: 4.8711
# Epoch [171/200], Step [25/40] Loss: 3.9151
# Epoch [171/200], Step [30/40] Loss: 4.3515
# Epoch [171/200], Step [35/40] Loss: 5.6896
# Epoch [171/200], Step [40/40] Loss: 4.6132
# Epoch [172/200], Step [5/40] Loss: 5.2896
# Epoch [172/200], Step [10/40] Loss: 5.2622
# Epoch [172/200], Step [15/40] Loss: 4.2602
# Epoch [172/200], Step [20/40] Loss: 4.8708
# Epoch [172/200], Step [25/40] Loss: 3.9149
# Epoch [172/200], Step [30/40] Loss: 4.3513
# Epoch [172/200], Step [35/40] Loss: 5.6892
# Epoch [172/200], Step [40/40] Loss: 4.6129
# Epoch [173/200], Step [5/40] Loss: 5.2892
# Epoch [173/200], Step [10/40] Loss: 5.2619
# Epoch [173/200], Step [15/40] Loss: 4.2599
# Epoch [173/200], Step [20/40] Loss: 4.8706
# Epoch [173/200], Step [25/40] Loss: 3.9146
# Epoch [173/200], Step [30/40] Loss: 4.3510
# Epoch [173/200], Step [35/40] Loss: 5.6889
# Epoch [173/200], Step [40/40] Loss: 4.6126
# Epoch [174/200], Step [5/40] Loss: 5.2889
# Epoch [174/200], Step [10/40] Loss: 5.2616
# Epoch [174/200], Step [15/40] Loss: 4.2596
# Epoch [174/200], Step [20/40] Loss: 4.8703
# Epoch [174/200], Step [25/40] Loss: 3.9143
# Epoch [174/200], Step [30/40] Loss: 4.3507
# Epoch [174/200], Step [35/40] Loss: 5.6885
# Epoch [174/200], Step [40/40] Loss: 4.6123
# Epoch [175/200], Step [5/40] Loss: 5.2886
# Epoch [175/200], Step [10/40] Loss: 5.2614
# Epoch [175/200], Step [15/40] Loss: 4.2592
# Epoch [175/200], Step [20/40] Loss: 4.8701
# Epoch [175/200], Step [25/40] Loss: 3.9140
# Epoch [175/200], Step [30/40] Loss: 4.3504
# Epoch [175/200], Step [35/40] Loss: 5.6882
# Epoch [175/200], Step [40/40] Loss: 4.6120
# Epoch [176/200], Step [5/40] Loss: 5.2883
# Epoch [176/200], Step [10/40] Loss: 5.2611
# Epoch [176/200], Step [15/40] Loss: 4.2589
# Epoch [176/200], Step [20/40] Loss: 4.8698
# Epoch [176/200], Step [25/40] Loss: 3.9137
# Epoch [176/200], Step [30/40] Loss: 4.3501
# Epoch [176/200], Step [35/40] Loss: 5.6878
# Epoch [176/200], Step [40/40] Loss: 4.6117
# Epoch [177/200], Step [5/40] Loss: 5.2880
# Epoch [177/200], Step [10/40] Loss: 5.2608
# Epoch [177/200], Step [15/40] Loss: 4.2586
# Epoch [177/200], Step [20/40] Loss: 4.8695
# Epoch [177/200], Step [25/40] Loss: 3.9134
# Epoch [177/200], Step [30/40] Loss: 4.3498
# Epoch [177/200], Step [35/40] Loss: 5.6874
# Epoch [177/200], Step [40/40] Loss: 4.6113
# Epoch [178/200], Step [5/40] Loss: 5.2876
# Epoch [178/200], Step [10/40] Loss: 5.2605
# Epoch [178/200], Step [15/40] Loss: 4.2583
# Epoch [178/200], Step [20/40] Loss: 4.8693
# Epoch [178/200], Step [25/40] Loss: 3.9131
# Epoch [178/200], Step [30/40] Loss: 4.3495
# Epoch [178/200], Step [35/40] Loss: 5.6870
# Epoch [178/200], Step [40/40] Loss: 4.6110
# Epoch [179/200], Step [5/40] Loss: 5.2873
# Epoch [179/200], Step [10/40] Loss: 5.2602
# Epoch [179/200], Step [15/40] Loss: 4.2579
# Epoch [179/200], Step [20/40] Loss: 4.8690
# Epoch [179/200], Step [25/40] Loss: 3.9128
# Epoch [179/200], Step [30/40] Loss: 4.3492
# Epoch [179/200], Step [35/40] Loss: 5.6866
# Epoch [179/200], Step [40/40] Loss: 4.6107
# Epoch [180/200], Step [5/40] Loss: 5.2869
# Epoch [180/200], Step [10/40] Loss: 5.2599
# Epoch [180/200], Step [15/40] Loss: 4.2575
# Epoch [180/200], Step [20/40] Loss: 4.8687
# Epoch [180/200], Step [25/40] Loss: 3.9124
# Epoch [180/200], Step [30/40] Loss: 4.3489
# Epoch [180/200], Step [35/40] Loss: 5.6862
# Epoch [180/200], Step [40/40] Loss: 4.6103
# model: 179
# Epoch [181/200], Step [5/40] Loss: 5.2865
# Epoch [181/200], Step [10/40] Loss: 5.2596
# Epoch [181/200], Step [15/40] Loss: 4.2571
# Epoch [181/200], Step [20/40] Loss: 4.8684
# Epoch [181/200], Step [25/40] Loss: 3.9121
# Epoch [181/200], Step [30/40] Loss: 4.3487
# Epoch [181/200], Step [35/40] Loss: 5.6858
# Epoch [181/200], Step [40/40] Loss: 4.6101
# Epoch [182/200], Step [5/40] Loss: 5.2864
# Epoch [182/200], Step [10/40] Loss: 5.2595
# Epoch [182/200], Step [15/40] Loss: 4.2570
# Epoch [182/200], Step [20/40] Loss: 4.8683
# Epoch [182/200], Step [25/40] Loss: 3.9120
# Epoch [182/200], Step [30/40] Loss: 4.3485
# Epoch [182/200], Step [35/40] Loss: 5.6857
# Epoch [182/200], Step [40/40] Loss: 4.6100
# Epoch [183/200], Step [5/40] Loss: 5.2863
# Epoch [183/200], Step [10/40] Loss: 5.2594
# Epoch [183/200], Step [15/40] Loss: 4.2569
# Epoch [183/200], Step [20/40] Loss: 4.8682
# Epoch [183/200], Step [25/40] Loss: 3.9119
# Epoch [183/200], Step [30/40] Loss: 4.3484
# Epoch [183/200], Step [35/40] Loss: 5.6855
# Epoch [183/200], Step [40/40] Loss: 4.6099
# Epoch [184/200], Step [5/40] Loss: 5.2862
# Epoch [184/200], Step [10/40] Loss: 5.2592
# Epoch [184/200], Step [15/40] Loss: 4.2568
# Epoch [184/200], Step [20/40] Loss: 4.8681
# Epoch [184/200], Step [25/40] Loss: 3.9117
# Epoch [184/200], Step [30/40] Loss: 4.3483
# Epoch [184/200], Step [35/40] Loss: 5.6854
# Epoch [184/200], Step [40/40] Loss: 4.6098
# Epoch [185/200], Step [5/40] Loss: 5.2860
# Epoch [185/200], Step [10/40] Loss: 5.2591
# Epoch [185/200], Step [15/40] Loss: 4.2567
# Epoch [185/200], Step [20/40] Loss: 4.8680
# Epoch [185/200], Step [25/40] Loss: 3.9116
# Epoch [185/200], Step [30/40] Loss: 4.3482
# Epoch [185/200], Step [35/40] Loss: 5.6853
# Epoch [185/200], Step [40/40] Loss: 4.6096
# Epoch [186/200], Step [5/40] Loss: 5.2859
# Epoch [186/200], Step [10/40] Loss: 5.2590
# Epoch [186/200], Step [15/40] Loss: 4.2565
# Epoch [186/200], Step [20/40] Loss: 4.8679
# Epoch [186/200], Step [25/40] Loss: 3.9115
# Epoch [186/200], Step [30/40] Loss: 4.3481
# Epoch [186/200], Step [35/40] Loss: 5.6851
# Epoch [186/200], Step [40/40] Loss: 4.6095
# Epoch [187/200], Step [5/40] Loss: 5.2858
# Epoch [187/200], Step [10/40] Loss: 5.2589
# Epoch [187/200], Step [15/40] Loss: 4.2564
# Epoch [187/200], Step [20/40] Loss: 4.8678
# Epoch [187/200], Step [25/40] Loss: 3.9114
# Epoch [187/200], Step [30/40] Loss: 4.3480
# Epoch [187/200], Step [35/40] Loss: 5.6850
# Epoch [187/200], Step [40/40] Loss: 4.6094
# Epoch [188/200], Step [5/40] Loss: 5.2856
# Epoch [188/200], Step [10/40] Loss: 5.2588
# Epoch [188/200], Step [15/40] Loss: 4.2563
# Epoch [188/200], Step [20/40] Loss: 4.8677
# Epoch [188/200], Step [25/40] Loss: 3.9113
# Epoch [188/200], Step [30/40] Loss: 4.3479
# Epoch [188/200], Step [35/40] Loss: 5.6848
# Epoch [188/200], Step [40/40] Loss: 4.6092
# Epoch [189/200], Step [5/40] Loss: 5.2855
# Epoch [189/200], Step [10/40] Loss: 5.2587
# Epoch [189/200], Step [15/40] Loss: 4.2561
# Epoch [189/200], Step [20/40] Loss: 4.8676
# Epoch [189/200], Step [25/40] Loss: 3.9111
# Epoch [189/200], Step [30/40] Loss: 4.3477
# Epoch [189/200], Step [35/40] Loss: 5.6846
# Epoch [189/200], Step [40/40] Loss: 4.6091
# Epoch [190/200], Step [5/40] Loss: 5.2854
# Epoch [190/200], Step [10/40] Loss: 5.2586
# Epoch [190/200], Step [15/40] Loss: 4.2560
# Epoch [190/200], Step [20/40] Loss: 4.8675
# Epoch [190/200], Step [25/40] Loss: 3.9110
# Epoch [190/200], Step [30/40] Loss: 4.3476
# Epoch [190/200], Step [35/40] Loss: 5.6845
# Epoch [190/200], Step [40/40] Loss: 4.6090
# Epoch [191/200], Step [5/40] Loss: 5.2852
# Epoch [191/200], Step [10/40] Loss: 5.2584
# Epoch [191/200], Step [15/40] Loss: 4.2559
# Epoch [191/200], Step [20/40] Loss: 4.8673
# Epoch [191/200], Step [25/40] Loss: 3.9109
# Epoch [191/200], Step [30/40] Loss: 4.3475
# Epoch [191/200], Step [35/40] Loss: 5.6843
# Epoch [191/200], Step [40/40] Loss: 4.6088
# Epoch [192/200], Step [5/40] Loss: 5.2851
# Epoch [192/200], Step [10/40] Loss: 5.2583
# Epoch [192/200], Step [15/40] Loss: 4.2557
# Epoch [192/200], Step [20/40] Loss: 4.8672
# Epoch [192/200], Step [25/40] Loss: 3.9108
# Epoch [192/200], Step [30/40] Loss: 4.3474
# Epoch [192/200], Step [35/40] Loss: 5.6842
# Epoch [192/200], Step [40/40] Loss: 4.6087
# Epoch [193/200], Step [5/40] Loss: 5.2849
# Epoch [193/200], Step [10/40] Loss: 5.2582
# Epoch [193/200], Step [15/40] Loss: 4.2556
# Epoch [193/200], Step [20/40] Loss: 4.8671
# Epoch [193/200], Step [25/40] Loss: 3.9106
# Epoch [193/200], Step [30/40] Loss: 4.3472
# Epoch [193/200], Step [35/40] Loss: 5.6840
# Epoch [193/200], Step [40/40] Loss: 4.6085
# Epoch [194/200], Step [5/40] Loss: 5.2848
# Epoch [194/200], Step [10/40] Loss: 5.2581
# Epoch [194/200], Step [15/40] Loss: 4.2554
# Epoch [194/200], Step [20/40] Loss: 4.8670
# Epoch [194/200], Step [25/40] Loss: 3.9105
# Epoch [194/200], Step [30/40] Loss: 4.3471
# Epoch [194/200], Step [35/40] Loss: 5.6838
# Epoch [194/200], Step [40/40] Loss: 4.6084
# Epoch [195/200], Step [5/40] Loss: 5.2846
# Epoch [195/200], Step [10/40] Loss: 5.2580
# Epoch [195/200], Step [15/40] Loss: 4.2553
# Epoch [195/200], Step [20/40] Loss: 4.8669
# Epoch [195/200], Step [25/40] Loss: 3.9104
# Epoch [195/200], Step [30/40] Loss: 4.3470
# Epoch [195/200], Step [35/40] Loss: 5.6837
# Epoch [195/200], Step [40/40] Loss: 4.6083
# Epoch [196/200], Step [5/40] Loss: 5.2845
# Epoch [196/200], Step [10/40] Loss: 5.2578
# Epoch [196/200], Step [15/40] Loss: 4.2551
# Epoch [196/200], Step [20/40] Loss: 4.8667
# Epoch [196/200], Step [25/40] Loss: 3.9102
# Epoch [196/200], Step [30/40] Loss: 4.3468
# Epoch [196/200], Step [35/40] Loss: 5.6835
# Epoch [196/200], Step [40/40] Loss: 4.6081
# Epoch [197/200], Step [5/40] Loss: 5.2843
# Epoch [197/200], Step [10/40] Loss: 5.2577
# Epoch [197/200], Step [15/40] Loss: 4.2550
# Epoch [197/200], Step [20/40] Loss: 4.8666
# Epoch [197/200], Step [25/40] Loss: 3.9101
# Epoch [197/200], Step [30/40] Loss: 4.3467
# Epoch [197/200], Step [35/40] Loss: 5.6833
# Epoch [197/200], Step [40/40] Loss: 4.6079
# Epoch [198/200], Step [5/40] Loss: 5.2842
# Epoch [198/200], Step [10/40] Loss: 5.2576
# Epoch [198/200], Step [15/40] Loss: 4.2548
# Epoch [198/200], Step [20/40] Loss: 4.8665
# Epoch [198/200], Step [25/40] Loss: 3.9099
# Epoch [198/200], Step [30/40] Loss: 4.3466
# Epoch [198/200], Step [35/40] Loss: 5.6831
# Epoch [198/200], Step [40/40] Loss: 4.6078
# Epoch [199/200], Step [5/40] Loss: 5.2840
# Epoch [199/200], Step [10/40] Loss: 5.2574
# Epoch [199/200], Step [15/40] Loss: 4.2547
# Epoch [199/200], Step [20/40] Loss: 4.8664
# Epoch [199/200], Step [25/40] Loss: 3.9098
# Epoch [199/200], Step [30/40] Loss: 4.3464
# Epoch [199/200], Step [35/40] Loss: 5.6829
# Epoch [199/200], Step [40/40] Loss: 4.6076
# Epoch [200/200], Step [5/40] Loss: 5.2839
# Epoch [200/200], Step [10/40] Loss: 5.2573
# Epoch [200/200], Step [15/40] Loss: 4.2545
# Epoch [200/200], Step [20/40] Loss: 4.8662
# Epoch [200/200], Step [25/40] Loss: 3.9096
# Epoch [200/200], Step [30/40] Loss: 4.3463
# Epoch [200/200], Step [35/40] Loss: 5.6827
# Epoch [200/200], Step [40/40] Loss: 4.6075
# model: 199
# ################
# convolution layers:(16,32,64)
# ################
# train data results
# 12151 12151 115849 115849
# accuracy: 99.52499999999999 %
# semi_correct: 100.0 %
# correct ones: 100.0 %
# correct zeros: 100.0 %
# ################
# test data results
# [0.1, 0.3, 0.5, 0.7, 0.9]
# j: 0.1
# accuracy: 97.41875 %
# semi_correct: 97.8125 %
# correct ones: 95.99072233267064 %
# correct zeros: 98.00220826720033 %
# j: 0.3
# accuracy: 97.709375 %
# semi_correct: 98.103125 %
# correct ones: 93.43936381709742 %
# correct zeros: 98.58877924228831 %
# j: 0.5
# accuracy: 97.884375 %
# semi_correct: 98.278125 %
# correct ones: 92.08084824387012 %
# correct zeros: 98.92346973983852 %
# j: 0.7
# accuracy: 97.94375 %
# semi_correct: 98.3375 %
# correct ones: 90.39098740888005 %
# correct zeros: 99.16499896487475 %
# j: 0.9
# accuracy: 97.70625 %
# semi_correct: 98.3125 %
# correct ones: 87.54141815772034 %
# correct zeros: 99.43413152991512 %
# res:
#     correct_ones  total_ones  correct_zeros  total_zeros
# 0          2897        3018          28403        28982
# 1          2820        3018          28573        28982
# 2          2779        3018          28670        28982
# 3          2728        3018          28740        28982
# 4          2642        3018          28818        28982 <class 'pandas.core.frame.DataFrame'>
